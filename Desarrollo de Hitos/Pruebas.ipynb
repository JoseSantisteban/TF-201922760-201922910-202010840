# %% [markdown]
# <a href="https://colab.research.google.com/github/JoseSantisteban/TF-201922760-201922910-202010840/blob/main/Pruebas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
roads = pd.read_csv("LibroCallesTp.csv")
roads
# Out:
#                  calle   interseccion
# 0           CamaraReal            C.A
# 1                  C.B       PaloRosa
# 2             PaloRosa     CamaraReal
# 3                  C.D            C.A
# 4                  C.B    C.Collasuyo
# ...                ...            ...
# 1271      CesarVallejo  AndresCaceres
# 1272      SanFrancisco           Yuta
# 1273  Av.Universitaria    Madreselvas
# 1274  Av.Universitaria       Alhelies
# 1275  Av.Universitaria         Proter
#
# [1276 rows x 2 columns]

# %%
roads['traffic weight']=np.random.randint(1,5,roads.shape[0])
roads['distancia']=np.random.randint(50,2000,roads.shape[0])

# %%
roads
# Out:
#                  calle   interseccion  traffic weight  distancia
# 0           CamaraReal            C.A               1        633
# 1                  C.B       PaloRosa               4       1603
# 2             PaloRosa     CamaraReal               1        598
# 3                  C.D            C.A               1        485
# 4                  C.B    C.Collasuyo               3       1206
# ...                ...            ...             ...        ...
# 1271      CesarVallejo  AndresCaceres               3       1000
# 1272      SanFrancisco           Yuta               1       1228
# 1273  Av.Universitaria    Madreselvas               2       1887
# 1274  Av.Universitaria       Alhelies               1        192
# 1275  Av.Universitaria         Proter               2       1089
#
# [1276 rows x 4 columns]

# %%
calles, intersec = roads['calle'],roads['interseccion']

# %%
import pprint
from collections import defaultdict


class Graph(object):

    def __init__(self, connections, directed=False):
        self._graph = defaultdict(set)
        self._directed = directed
        self.add_connections(connections)

    def add_connections(self, connections):
        for node1, node2 in connections:
            self.add(node1, node2)

    def add(self, node1, node2):
        self._graph[node1].add(node2)
        if not self._directed:
            self._graph[node2].add(node1)

    def remove(self, node):
        for n, cxns in self._graph.items():  
            try:
                cxns.remove(node)
            except KeyError:
                pass
        try:
            del self._graph[node]
        except KeyError:
            pass

    def is_connected(self, node1, node2):
        return node1 in self._graph and node2 in self._graph[node1]

    def find_path(self, node1, node2, path=[]):
        #cambiar aqui por Requisitos del TF
        path = path + [node1]
        if node1 == node2:
            return path
        if node1 not in self._graph:
            return None
        for node in self._graph[node1]:
            if node not in path:
                new_path = self.find_path(node, node2, path)
                if new_path:
                    return new_path
        return None

    def __str__(self):
        return '{}({})'.format(self.__class__.__name__, dict(self._graph))

# %%
connections = list(zip(calles, intersec))
g = Graph(connections, directed=True)
pretty_print = pprint.PrettyPrinter()
pretty_print.pprint(g._graph)
# Out:
# defaultdict(<class 'set'>,
#             {'12Febrero': {'30Marzo',
#                            '4Agosto',
#                            'AugustoLeguia',
#                            'ManuelPrado',
#                            'NicolasPierola'},
#              '23Septiembre': {'12febrero',
#                               '3Octubre',
#                               '4Agosto',
#                               'AugustoLeguia',
#                               'ManuelPrado',
#                               'NicolasPierola',
#                               'PardoBarreda',
#                               'SanchezCerro'},
#              '30Marzo': {'LasTunas'},
#              '3Diciembre': {'Angeles', 'GarcilazoVega'},
#              '3Octubre': {'Olivos', 'SantaRosa'},
#              '4Agosto': {'Nisperos'},
#              '9Octubre': {'America'},
#              'AbrahamValdelomar': {'Calle3',
#                                    'CesarVallejo',
#                                    'JoseMariaArguedas'},
#              'Acacias': {'SantaRosa', 'Naranjos'},
#              'Achallau': {'LaFlor'},
#              'Achiras': {'SantoDomingo', 'Lucumas', 'Naranjos'},
#              'AgustinGamarra': {'Carnelias'},
#              'Alarcon': {'2Diciembre'},
#              'Alegre': {'Ancash'},
#              'AlfonsoUgarte': {'MiguelGrau'},
#              'Alinut': {'C.18'},
#              'Amancaes': {'AlfonsoUgarte'},
#              'Amapolas': {'Archiras',
#                           'Billinghurst',
#                           'Central',
#                           'Cipreses',
#                           'ManuelPrado',
#                           'Petunias',
#                           'Primulas',
#                           'TorresPacifico'},
#              'America': {'Florales'},
#              'Ancash': {'LosRobles', ' LaLibertad'},
#              'AndresCaceres': {'JironAbelardoQuiñones',
#                                'MicaelaBastidas',
#                                'Recuay',
#                                'Trivago'},
#              'Angamos': {'31Mayo',
#                          '3Octubre',
#                          'Claudivilla',
#                          'DiegoFerre',
#                          'EliasAguirre',
#                          'EnriquePalacios',
#                          'LaQuina',
#                          'LaRivera',
#                          'LasPalmas',
#                          'LasTunas',
#                          'LosAndes',
#                          'LosCerezos',
#                          'LosJuniperos',
#                          'LosLaureles',
#                          'LosSauces',
#                          'ManuelScorza',
#                          'MicaelaBastidas',
#                          'MiguelGrau',
#                          'ParadoBellido',
#                          'PardoBarreda',
#                          'Recuay'},
#              'Angeles': {'GarcilazoVega'},
#              'Antisuyo': {'Contisuyo'},
#              'AntisuyoCalleC': {'Puruchuco', 'Lisboa', 'C.Collasuyo'},
#              'AntonioBastidas': {'JoseYepez', 'Sausa', 'LucasColqui'},
#              'Arandanos': {'Lirios', 'Naranjos'},
#              'Arguedas': {'Altamirano'},
#              'AugistoLeguia': {'FloresNorte'},
#              'AugustoLeguia': {'12Febrero',
#                                '23Septiembre',
#                                'AndresCaceres',
#                                'ArguedaSantamirano',
#                                'Aux.TupacAmaru',
#                                'Aux.Universitaria',
#                                'Ayacucho',
#                                'CarlosMariategui',
#                                'LasGuanabanas',
#                                'LeninSolano',
#                                'LosTulipanes',
#                                'ManuelOdria',
#                                'MicaelaBastidas',
#                                'Primavera',
#                                'SimonBoliva',
#                                'VargasMachuca'},
#              'AugustoSalaverry': {'JuanGonzaloRose', 'Av.JoseCarlosMariategui'},
#              'Aun.Uni': {'Geranios'},
#              'Aux.TupacAmaru': {' Carmen',
#                                 ' DelCarmen',
#                                 ' JosePardo',
#                                 ' ParqueZonal',
#                                 '3Octubre',
#                                 'AlfonsoUgarte',
#                                 'AndresCaceres',
#                                 'AugustoLeguia',
#                                 'BustamanteRivero',
#                                 'CaminoReal',
#                                 'Central',
#                                 'ElDorado',
#                                 'Florales',
#                                 'JoseBalta',
#                                 'Lazmines',
#                                 'LosClaveles',
#                                 'LosCrisantemos',
#                                 'LosGeranios',
#                                 'LosLaureles',
#                                 'LosRosales',
#                                 'ManuelPrado',
#                                 'MiguelGrau',
#                                 'Miraflores',
#                                 'NicolasPierola',
#                                 'OscarBenavides',
#                                 'PardoYBarreda',
#                                 'PasajeGeranios',
#                                 'RamonCastilla',
#                                 'SamaneSocampo',
#                                 'SanchezCerro'},
#              'Aux.Uni': {' Universitaria',
#                          '3Octubre',
#                          'AgustinGamarra',
#                          'AugustoLeguia',
#                          'Ayacucho',
#                          'C.7',
#                          'CaminoReal',
#                          'ChavinHuantar',
#                          'Huaralino',
#                          'JardinesI',
#                          'LasOrtencias',
#                          'LasTunas',
#                          'LosAlamos',
#                          'LosRobles',
#                          'Luzmila',
#                          'Parquezonal',
#                          'Recuay',
#                          'SanchesCerro',
#                          'Skinner',
#                          'VirgenDelCarmen'},
#              'AuxiliarAv.ChimpuOcllo': {'Av.MarianoCondorcanqui',
#                                         'C.10',
#                                         'FranciscoTorres',
#                                         'SalasPachacutec'},
#              'AuxiliarHeroesdelAltoCanepa': {'Ca.RosaTupacAmaru',
#                                              'Jr.DiegoOrtizola',
#                                              'Pje.A'},
#              'Av.A': {'LasFrambuesas'},
#              'Av.ChimpuOcllo': {'AndresCaceres',
#                                 'Av.JoseCarlosMariategui',
#                                 'Av.MarianoCondorcanqui',
#                                 'C.14',
#                                 'Ca.Jr.GuillermoProtzel',
#                                 'Chinchaysuyo',
#                                 'JironArmandoRevoredoIglesias'},
#              'Av.JoseCarlosMariategui': {'AugustoSalaverry',
#                                          'Av.TupacAmaru',
#                                          'Frambuosio',
#                                          'Trivago'},
#              'Av.MarianoCondorcanqui': {'AuxiliarAv.ChimpuOcllo',
#                                         'Av.ChimpuOcllo',
#                                         'Av.SeñordeCaudivilla',
#                                         'Av.U',
#                                         'C.MiguelLanda',
#                                         'Contisuyo',
#                                         'FranciscoWambo',
#                                         'Humboldt',
#                                         'JironCarlosMartinezdePinillos',
#                                         'JironJuanOConnor',
#                                         'JironSantiagodeCardenas',
#                                         'Pereda',
#                                         'Sr.deSipan'},
#              'Av.MerinoReynaOeste': {'Av.SeñordeCaudivilla'},
#              'Av.SanFelipe': {'AuxiliarHeroesdelAltoCanepa', 'VenturaMonjaras'},
#              'Av.SeñordeCaudivilla': {'AbrahamValdelomar',
#                                       'Av.MarianoCondorcanqui',
#                                       'Av.Universitaria',
#                                       'C.MunicipalidadCarabayllo',
#                                       'Ca.Jr.GuillermoProtzel',
#                                       'Ca.Mercadona',
#                                       'HeroesdelaPaz',
#                                       'JironJuanValer',
#                                       'JoseCarlosMariategui',
#                                       'JoseSavogal',
#                                       'Lisboa',
#                                       'MartiresdelaPolicia',
#                                       'SanFrancisco',
#                                       'SanMartin',
#                                       'Unanue',
#                                       'VictorHumareda'},
#              'Av.SeñordeCaudivillas': {'SanJudas'},
#              'Av.TupacAmaru': {'AlfonsoUgarte',
#                                'Av.JoseCarlosMariategui',
#                                'Av.MerinoReynaOeste',
#                                'Av.SeñordeCaudivilla',
#                                'Calle5',
#                                'Humbrella',
#                                'JironAbelardoQuiñones',
#                                'JoseGalvez',
#                                'Yuta'},
#              'Av.U': {'Av.U2',
#                       'C.17',
#                       'C.18',
#                       'C.21',
#                       'C.22',
#                       'C.23',
#                       'C.25',
#                       'C.9',
#                       'C.Q',
#                       'C.W',
#                       'C.Y',
#                       'Calle.W',
#                       'CalleFlorestala',
#                       'Floresta',
#                       'IglesiaAdventista',
#                       'Jr.Pacifico',
#                       'MarianoCondorcanqui',
#                       'Parque15',
#                       'TrapicheChillon',
#                       'Universitaria'},
#              'Av.Univeristaria': {'C.Huchura'},
#              'Av.Universitaria': {'Alhelies',
#                                   'AugutoSalaverry',
#                                   'Av.SeñordeCaudivilla',
#                                   'C.MarianoMendigure',
#                                   'Calle3',
#                                   'CesarVallejo',
#                                   'Madreselvas',
#                                   'PasajeF1',
#                                   'Proter',
#                                   'Scorza'},
#              'Ayacucho': {'MiguelGrau', 'Union'},
#              'AymiTupac': {'AuxiliarAv.ChimpuOcllo',
#                            'C.10',
#                            'C.12',
#                            'C.4',
#                            'C.5',
#                            'C.9',
#                            'Ca.FranciscoTupacAmaru',
#                            'Ca.RosaTupacAmaru',
#                            'JoseYepez',
#                            'Jr.DiegoOrtizola',
#                            'LucasColqui',
#                            'Pje.Q',
#                            'Sausa'},
#              'Azucena': {'Reiko'},
#              'Benavides': {'AntonioRaimondi',
#                            'ArguedazSantamirado',
#                            'Aux.TupacAmaru',
#                            'Baldelomar',
#                            'Benites',
#                            'CarlosMareategui',
#                            'Chimpuocllo',
#                            'CoronelSandoval',
#                            'JoseSantosChocano',
#                            'JulioCesarTello',
#                            'Jzela',
#                            'Kioto',
#                            'LaBola',
#                            'LaCultura',
#                            'LaTierra',
#                            'LeninSolano',
#                            'Luzoli',
#                            'ManuelOdria',
#                            'ManuelPrado',
#                            'MargaritaVelfas',
#                            'Marte',
#                            'Pachacamau',
#                            'ParadoBellido',
#                            'Rasauri',
#                            'SalazarBondi',
#                            'SanMartin',
#                            'SanchezCarrion',
#                            'Tokio',
#                            'Yen',
#                            'Zendal'},
#              'Benitez': {'SanchezCarrion'},
#              'Biiinghurst': {'SantaRosa'},
#              'Billinghurst': {'12Febrero',
#                               'Aux.Uni',
#                               'Lucumas',
#                               'Orquideas',
#                               'Rosas',
#                               'SantoDomingo',
#                               'Tulipanes'},
#              'BuenaVista': {'SanchezCerro'},
#              'Bustamante': {'Nardos', 'SanMartin', 'Naranjos'},
#              'Bytetect': {' ParqueCarabayllo'},
#              'C': {'J'},
#              'C.10': {'Av.MerinoReynaOeste', 'C.4', 'C.2', 'C.Collasuyo'},
#              'C.11': {'C.Collasuyo',
#                       'C.S',
#                       'Calle4',
#                       'Malecon',
#                       'TrapicheChillon'},
#              'C.12': {'C.9', 'C.5', 'C.Collasuyo', 'C.7'},
#              'C.13': {'Avenue3',
#                       'AymiTupac',
#                       'C.11',
#                       'C.5',
#                       'C.8',
#                       'LosGallinazos'},
#              'C.14': {'C.N',
#                       'Ca.Jr.GuillermoProtzel',
#                       'Calle15',
#                       'JironJuanValer',
#                       'MartiresdelaPolicia'},
#              'C.17': {'Fatiuo'},
#              'C.18': {'C.11', 'ManuelPrado', 'C.22', ' Av.U', 'Parque'},
#              'C.2': {'Aux.Uni', 'ParquePacayal', 'Caudivilla'},
#              'C.21': {'Universitaria', 'C.24'},
#              'C.22': {'Calle3'},
#              'C.24': {'C.Q'},
#              'C.25': {'C.21', 'C.20'},
#              'C.3': {'Aux.Uni', 'C.2'},
#              'C.4': {'Ca.3', 'C.9', 'C.5'},
#              'C.5': {'C.10', 'C.9', 'AymiTupac'},
#              'C.7': {'Ca.3', 'C.13'},
#              'C.8': {'Ca.3', 'Caudivilla'},
#              'C.9': {'AymiTupac',
#                      'C.12',
#                      'C.2',
#                      'C.5',
#                      'C.7',
#                      'C.8',
#                      'C.Collasuyo',
#                      'C.Y',
#                      'Ca.3',
#                      'Gallinazos'},
#              'C.A': {'C.Collasuyo'},
#              'C.Ayacucho': {'Ancash'},
#              'C.B': {'PaloRosa', 'C.Collasuyo'},
#              'C.Collasuyo': {'Av.JoseCarlosMariategui',
#                              'Av.MerinoReynaOeste',
#                              'Av.SeñordeCaudivilla',
#                              'C.10',
#                              'C.11',
#                              'C.13',
#                              'C.8',
#                              'C.D',
#                              'C.F',
#                              'C.G',
#                              'C.MachuPicchu',
#                              'C.Paucartambo',
#                              'Ca.HuacadelSol',
#                              'Ca.Mercadona',
#                              'Contisuyo',
#                              'PaloRosa'},
#              'C.D': {'C.A'},
#              'C.DanielAlcidesCarrion': {'MicaelaBastidas'},
#              'C.F': {'Frambuosio'},
#              'C.Floresta': {'C.V', 'C.13', 'C.Y'},
#              'C.G': {'ProlMerinoReyna', 'Frambuosio'},
#              'C.Huchura': {'C.MarianoMendigure', 'Castro'},
#              'C.LeonardoAlvariñoHerrera': {'JoseQuiñonesGonzales'},
#              'C.MarianoMendigure': {'NicolasaTorres', 'Pukin'},
#              'C.MiguelLanda': {'Acoscamayta',
#                                'Av.MarianoCondorcanqui',
#                                'C.10',
#                                'C.FranciscaHerrera',
#                                'Castro',
#                                'Mamani'},
#              'C.Moscu': {'C.MunicipalidadCarabayllo'},
#              'C.MunicipalidadCarabayllo': {'Av.MerinoReynaOeste',
#                                            'Ca.Londres',
#                                            'Calle5',
#                                            'Trulio',
#                                            'Yuta'},
#              'C.N': {'Av.U', 'C.LL'},
#              'C.Paucartambo': {'Lisboa'},
#              'C.Q': {' C.21',
#                      'C.24',
#                      'C.N',
#                      'C.R',
#                      'Claudivilla',
#                      'Universitaria'},
#              'C.V': {'Av.U', 'C.O'},
#              'C.W': {'C.13'},
#              'C.Y': {'C.9', 'C.22', 'Parque15'},
#              'Ca.3': {'C.13', 'C.12', 'Claudivilla'},
#              'Ca.FelipeMendizabal': {'AndresPoma'},
#              'Ca.FranciscoTupacAmaru': {'JoseYepez', 'Ca.RosaTupacAmaru'},
#              'Ca.JoseSantosChocano': {'AugustoSalaverry'},
#              'Ca.Jr.GuillermoProtzel': {'JironRaulJimenezChavez'},
#              'Ca.Mercadona': {'Prol.MerinoReyna'},
#              'Ca.Pazos': {'ParqueFlorida'},
#              'Calendulas': {'Billinghurst'},
#              'Calle1': {'Calle2'},
#              'Calle10': {'Calle111'},
#              'Calle15': {'JironRaulJimenezChavez'},
#              'Calle6': {'Huambos', 'LasFlores'},
#              'Calle7': {'AguasMarinas', 'Calle11', 'Calle8'},
#              'Calle8': {'Calle9', 'Calle10'},
#              'Calveles': {'DienteLeon'},
#              'CamaraReal': {'Av.A', 'C.A'},
#              'CaminoReal': {' Universitaria',
#                             'Aux.Uni',
#                             'C.18',
#                             'C.9',
#                             'C.Q',
#                             'C.Y',
#                             'Eucaliptos',
#                             'JazminesYCaminoReal',
#                             'LosPortales',
#                             'LosRomeros',
#                             'LosSauces',
#                             'Malecon',
#                             'MicaelaBastidas',
#                             'ParqueZonal',
#                             'Rivera',
#                             'SantoDomingo',
#                             'SolVilla',
#                             'TupacAmaru'},
#              'Campanillas': {'Retamas'},
#              'Carhuaz': {'Angamos'},
#              'CarlosMariategui': {'Cruz'},
#              'Carolina': {'LosJardines', 'SantaRosa'},
#              'Casuarinas': {'AguasMarinas', 'Skynner'},
#              'Cedros': {'Robles', 'TupacAmaru'},
#              'Centar': {'Santos'},
#              'Central': {'Sauces'},
#              'CesarVallejo': {'AndresCaceres',
#                               'Av.JoseCarlosMariategui',
#                               'Av.TupacAmaru',
#                               'JoseSavogal',
#                               'JuanGonzaloRose',
#                               'SanJudas'},
#              'ChavinHuantar': {'Hayllapampa', 'Huaralino'},
#              'Chiclayo': {'Alhelles', 'Piura'},
#              'ChillonTrapiche': {'Albedrio',
#                                  'Av.ChimpuOcllo',
#                                  'C.ClaudioBaltazarMontoya',
#                                  'C.LeonardoAlvariñoHerrera',
#                                  'JironRaulJimenezChavez',
#                                  'Truquesio'},
#              'Chinchaysuyo': {'AntisuyoCalleC',
#                               'Av.SeñordeCaudivilla',
#                               'C.Collasuyo',
#                               'C.MachuPicchu',
#                               'Ca.HuacadelSol',
#                               'Contisuyo',
#                               'Sr.deSipan'},
#              'Chontas': {'SanMartin'},
#              'Cienpies': {'Liturgia', 'Santeola'},
#              'Cipreses': {'Amapolas', 'Lirios'},
#              'Ciruelas': {'Manzanas', 'Claveles', 'TorresPacifico'},
#              'Ciruelos': {'SanIsidro', 'SanMartin'},
#              'Claudivilla': {'MancoCapac', 'Dalias'},
#              'Claveles': {'Higos', 'SantaRosa', 'Lucumas', 'Magnolias'},
#              'Colibries': {'Luzmilla'},
#              'Colla': {'ManuelOdria'},
#              'Collasuyo': {'CoronelManuelSandoval',
#                            'Dalias',
#                            'Kioto',
#                            'LosAngeles',
#                            'Luzoli',
#                            'ManuelPrado',
#                            'ParadoBellido',
#                            'Silvertes',
#                            'Tokio',
#                            'Yen',
#                            'Zendal'},
#              'Continsuyo': {'Ca.Jr.GuillermoProtzel'},
#              'Contisuyo': {'Av.MarianoCondorcanqui',
#                            'C.17',
#                            'Collasuyo',
#                            'HeroesdelaPaz',
#                            'JironJuanValer',
#                            'Lisboa',
#                            'Ollantaytambo'},
#              'Cruz': {'Monique'},
#              'Custamante': {'SantaRosa'},
#              'Dalias': {'SantoDomingo'},
#              'DiegoFerre': {'Juniperos', 'LosJuniperos'},
#              'Duraznos': {'Ciruelas'},
#              'ElDomo': {'LosLaureles'},
#              'ElDorado': {'LasLlantanas'},
#              'ElisabethLoginote': {'Sucursal'},
#              'EnriquePalacios': {'LosJuniperos', 'JoseOlaya'},
#              'Eucaliptos': {'Bonsai',
#                             'CaminoReal',
#                             'ElBosque',
#                             'LasPalmeras',
#                             'LosAlamos',
#                             'LosCipreses',
#                             'LosLirios',
#                             'LosPinos',
#                             'LosRosales',
#                             'ParqueZonal',
#                             'SanMartin'},
#              'FedericoVillareal': {'Chayan', 'Ca.Pazos'},
#              'Ficus': {'Alisos'},
#              'FlorCerezo': {'Hayllapampa'},
#              'FlorLoto': {'Amapolas'},
#              'FlorLoto-Hayllapampa': {nan},
#              'Florales': {'Ancash'},
#              'Frambuesas': {'Duraznos', 'Pacaes', 'Toronjas'},
#              'Frambusio': {'Av.JoseCarlosMariategui'},
#              'FranciscoTorres': {'Ca.FelipeMendizabal',
#                                  'FranciscoWambo',
#                                  'JoseYepez',
#                                  'Jr.DiegoOrtizola',
#                                  'Jr.MateoAvellaneda',
#                                  'MelchorArteaga',
#                                  'Pereda',
#                                  'Pje.Q'},
#              'FranciscoWambo': {'Enriquez', 'Mamani', 'AndresPoma'},
#              'Frecker': {'Santos'},
#              'Fresas': {'C.13', 'Lucumas'},
#              'Galaspagos': {'Aves'},
#              'Gallinazos': {'C.5', 'C.11'},
#              'Geranios': {'Tulipanes'},
#              'Geranlos': {'Tacna'},
#              'Gorriones': {'Colibries',
#                            'Pacayal',
#                            'SantaMarta',
#                            'VirgerDelCarmen'},
#              'GregorioSisa': {'JoseAmaro', 'EstebanBaca'},
#              'Hayllapampa': {'ManuelPrado'},
#              'HerbertTweddle': {'C.LeonardoAlvariñoHerrera',
#                                 'C.V',
#                                 'Contisuyo',
#                                 'Fatiuo',
#                                 'JironCarlosMartinezdePinillos',
#                                 'JironRaulJimenezChavez',
#                                 'Truquesio'},
#              'HeroesdelaPaz': {'C.14'},
#              'Higos': {'Aux.Uni',
#                        'Ciruelas',
#                        'Magnolias',
#                        'Manzanos',
#                        'Rosas',
#                        'SantaRosa'},
#              'Huaralino': {'Huambos', 'ChavinHuantar'},
#              'Huayallapampa': {'Cipreses'},
#              'Ica': {'1Mayo', 'Ica2'},
#              'IglesiaAdventista': {'C.22'},
#              'JIronCarlosMartinezdePinillos': {'Alfabeto'},
#              'Jacarandas': {'Ciruelas', 'Lucumas', 'Magnolias'},
#              'Jacintos': {'SantaRosa', 'Naranjos'},
#              'Jaricza': {'Uriarte', 'Santos'},
#              'JavierHeraud': {'AugustoSalaverry', 'Av.CarlosMariategui'},
#              'Jazmines': {'Liurnia', 'CaminoReal'},
#              'JironAbelardoQuiñones': {'MiguelGrau', 'JoseOlaya'},
#              'JironArmandoRevoredoIglesias': {'C.ClaudioBaltazarMontoya',
#                                               'C.LeonardoAlvariñoHerrera',
#                                               'C.V',
#                                               'JironCarlosMartinezdePinillos'},
#              'JironCarlosMartinezdePinillos': {'C.14',
#                                                'C.16',
#                                                'C.PedroPauletMostajo',
#                                                'Ca.Jr.GuillermoProtzel'},
#              'JironJuanOConnor': {'Ca.Jr.GuillermoProtzel', 'C.16'},
#              'JironJuanValer': {'JironRaulJimenezChavez'},
#              'JironSantiagodeCardenas': {'C.14',
#                                          'C.16',
#                                          'Ca.Jr.GuillermoProtzel',
#                                          'Ca.PedroPauletMostajo'},
#              'JorgeChavez': {'C.DanielAlcidesCarrion', 'JoseOlaya'},
#              'JoseAmaro': {'JuandeDiosValencia'},
#              'JoseBalta': {'ArguedaSantamirano',
#                            'AugustoLeguia',
#                            'Aux.TupacAmaru',
#                            'Ayacucho',
#                            'CarlosMareategui',
#                            'Jr.7Febrero',
#                            'ManuelOdria',
#                            'NicolasPierola',
#                            'Olivos',
#                            'SanJose',
#                            'SimonBolivar',
#                            'VargasMachuca'},
#              'JoseCarlosMariategui': {'Av.SeñordeCaudivilla'},
#              'JoseGalvez': {'AndresA.Caceres',
#                             'DanielAlcidesCarrion',
#                             'MiguelGrau'},
#              'JoseOlaya': {'DiegoFerre'},
#              'JosePardo': {'Tacna'},
#              'JoseQuiñonesGonzales': {'Albedrio',
#                                       'Av.SeñordeCaudivilla',
#                                       'JironRaulJimenezChavez',
#                                       'Truquesio'},
#              'JoseRivaguero': {nan},
#              'JoseSavogal': {'RicardoPalma', 'JoseMariaArguedas'},
#              'Jr.DiegoOrtizola': {'Ca.FranciscoTupacAmaru', 'AntonioBastidas'},
#              'Jr.MateoAvellaneda': {'Enriquez', 'AndresPoma'},
#              'Jr.Pacifico': {'IglesiaAdventista', 'C.18'},
#              'Jr.SanJose': {'C.11'},
#              'Jr.Trebol': {'Orquideas', 'Cantuta', 'Cactus'},
#              'Jr7Febrero': {'SanMartin'},
#              'JuanGonzaloRose': {'JavierHeraud', 'Ca.JoseSantosChocano'},
#              'JuandeDiosValencia': {'EstebanBaca', 'MelchorArteaga'},
#              'L': {'N', 'J'},
#              'LaCapilla': {'Carmen'},
#              'LaFlor': {'Marcona'},
#              'LaLibertad': {'Angamos', 'Tulipanes'},
#              'LaQuina': {'3Octubre'},
#              'LaRivera': {'Angamos', 'LasGuanabanas'},
#              'LasCerezas': {'LosTulipanes', ' Los Alamos', 'Guanabanas'},
#              'LasFlores': {'Calle7'},
#              'LasFrambuesas': {'LasManzanas'},
#              'LasGardenias': {'LosJardines'},
#              'LasGerberas': {'31Mayo'},
#              'LasHortencias': {'SolVilla'},
#              'LasLlantanas': {'31Mayo'},
#              'LasTunas': {'3Octubre', 'LasPalmas'},
#              'LeninSolano': {'AndresCaceres'},
#              'Lirios': {'Manzanos', 'Sanna', 'TorresPacifico'},
#              'LosAlamos': {'LaRivera'},
#              'LosAlgarrobos': {'C.O'},
#              'LosAndes': {'Angamos',
#                           'Claudivilla',
#                           'LosSauces',
#                           'ManuelScorza',
#                           'Miraflores'},
#              'LosAngeles': {'SantoDomingo', 'Principal'},
#              'LosCipreses': {'Eucaliptos',
#                              'LosCrisantemos',
#                              'LosNogales',
#                              'Nisperos'},
#              'LosClaveles': {'LosLaureles', 'LasGerberas'},
#              'LosCrocus': {'ManuelScorza', 'MicaelaBastidas'},
#              'LosFaiques': {'LosTulipanes', 'LosAlisis'},
#              'LosGeranios': {' Caudivilla',
#                              'Angeles',
#                              'Aux.TupacAmaru',
#                              'Colla',
#                              'Lirios',
#                              'LosLaureles',
#                              'LosSauces',
#                              'MicaelaBastidas',
#                              'Orquideas',
#                              'SanJose',
#                              'SimonBolivar',
#                              'Tulipanes',
#                              'VargasMachuca'},
#              'LosJardines': {'LosPortales'},
#              'LosJazmines': {'LosCactus'},
#              'LosJuniperos': {'Angamos'},
#              'LosLaureles': {'VargasMachuca'},
#              'LosMangos': {'LosTulipanes'},
#              'LosNogales': {'Bonsai'},
#              'LosOlivos': {'1Mayo',
#                            'Central',
#                            'Galapagos',
#                            'LasGlicinas',
#                            'LosAlisos',
#                            'LosCedros',
#                            'LosCrisantemos',
#                            'LosFicus',
#                            'LosNogales',
#                            'Sauces',
#                            'Valegre'},
#              'LosPortales': {'Ayacucho', 'RamonCastilla'},
#              'LosRobles': {'Tulipanes'},
#              'LosRosales': {'LaUnion'},
#              'LosSauces': {'31Mayo',
#                            'Angamos',
#                            'Antisuyo',
#                            'Ca.2',
#                            'CaminoReal',
#                            'Claudivilla',
#                            'Collasuyo',
#                            'Contisuyo',
#                            'Cuadra2',
#                            'ElDorado',
#                            'LasLlantanas',
#                            'LosAlgarrobos',
#                            'LosAndes',
#                            'LosCedros',
#                            'LosCrisantemos',
#                            'LosCrocus',
#                            'LosFicus',
#                            'LosGeranios',
#                            'LosLaureles',
#                            'LosTulipanes',
#                            'Miraflores',
#                            'PaloRosa',
#                            'PaloSanto',
#                            'ParqueZonal',
#                            'SolNaciente',
#                            'VargasMachuca'},
#              'LosTulipanes': {'ElDorado'},
#              'Lucaria': {'Auxiliar'},
#              'Lucario': {'Liturgia'},
#              'Lucumas': {'Peonias', 'Av.A', 'Fresas'},
#              'Luzmila': {'Gorriones'},
#              'Luzmilla': {'Gorriones'},
#              'M.Prado': {'SantoDomingo'},
#              'Magnolias': {'Pacayal'},
#              'Malecon': {'Jr.Sanjose'},
#              'Mamani': {'Pereda'},
#              'MancoCapac': {'TeresaCalcuta'},
#              'ManuelPardo': {'MiguelGrau'},
#              'ManuelPrado': {' LosNaranjos',
#                              ' SantoDomingo',
#                              '12Febrero',
#                              '23Septiembre',
#                              'AntonioRaimondi',
#                              'ArguedazSantamirado',
#                              'Aux.TupacAmaru',
#                              'Aux.Uni',
#                              'Ayacucho',
#                              'C.Collasuyo',
#                              'CarlosMareategui',
#                              'Chimpuocllo',
#                              'FrancisVega',
#                              'Huayllapampa',
#                              'Jazminez',
#                              'JosePardo',
#                              'JulioCesarTello',
#                              'Jzela',
#                              'Kioto',
#                              'LaBola',
#                              'LaCultura',
#                              'LeninSolano',
#                              'LuisEnriqueI',
#                              'LuzOli',
#                              'ManuelODria',
#                              'MargaritaBelFast',
#                              'MicaelaBastidas',
#                              'OscarBenavides',
#                              'ParadoBellido',
#                              'Primeravera',
#                              'SalazarBondi',
#                              'SanPedroCarabayllo',
#                              'SantaRosa',
#                              'Sendal',
#                              'SimonBolivar',
#                              'Tokio',
#                              'TupacAmaru',
#                              'Universitaria',
#                              'Yen'},
#              'ManuelScorza': {'LosClaveles', 'LosAndes'},
#              'Manzanas': {'Lucumas'},
#              'Manzanos': {'Ciruelas', 'SantaRosa'},
#              'Margaritas': {'AgustinGamarra',
#                             'Luzmilla',
#                             'SanMartin',
#                             'VirgenDelCarmen'},
#              'MarianoCondorcanqui': {'Algarrobos',
#                                      'Av.U',
#                                      'C.21',
#                                      'C.M',
#                                      'C.N',
#                                      'C.O',
#                                      'C.Q',
#                                      'C.R',
#                                      'C23',
#                                      'ParqueZonal',
#                                      'S',
#                                      'SanPedroClaves'},
#              'Maruja': {'Loiza', 'Geminis'},
#              'Mendiola': {'Benitez'},
#              'MicaelaBastidas': {nan,
#                                  '1Mayo',
#                                  '31Mayo',
#                                  '3Octubre',
#                                  'AndresCaceres',
#                                  'Anylla',
#                                  'AugustoLeguia',
#                                  'AvenidaAngamos',
#                                  'C.7',
#                                  'CaminoReal',
#                                  'Collasuyo',
#                                  'DelCarmen',
#                                  'DiegoFerre',
#                                  'EliasAguirre',
#                                  'ElisabethLoginote',
#                                  'EnriquePalacios',
#                                  'Frecker',
#                                  'Geranlos',
#                                  'Geranlos2',
#                                  'JoseBalta',
#                                  'JoseOlaya',
#                                  'LasLantanas',
#                                  'LasPalmeras',
#                                  'Leona',
#                                  'LosAlamos',
#                                  'LosClaveles',
#                                  'LosCrocus',
#                                  'LosLaureles',
#                                  'LosPinos',
#                                  'LosRosales',
#                                  'LosTulipanes',
#                                  'ManuelEscorza',
#                                  'ManuelPrado',
#                                  'ManuesScorza',
#                                  'Michela',
#                                  'MiguelGrau',
#                                  'Milei',
#                                  'NicolasPierola',
#                                  'Palmera',
#                                  'Palmeras',
#                                  'Paloma',
#                                  'PardoBarreda',
#                                  'RamonCastilla',
#                                  'SanGabriel',
#                                  'SanchezCerro',
#                                  'SantaRosa',
#                                  'SolNaciente',
#                                  'Tacna'},
#              'Michela': {'Milei', 'SanGabriel'},
#              'MiguelAnco': {'GregorioSisa'},
#              'MiguelGrau': {'JorgeChavez'},
#              'Milei': {'MicaelaBastidas'},
#              'Miraflores': {'2Diciembre',
#                             '31Mayo',
#                             '3Diciembre',
#                             'Alamos',
#                             'Alcones',
#                             'Aux.TupacAmaru',
#                             'Avancaes',
#                             'Cantuta',
#                             'Cartura',
#                             'Claudivilla',
#                             'Jr.Trebol',
#                             'LosSauces',
#                             'ManuelScorza',
#                             'Orquideas',
#                             'Tulipanes',
#                             'TupacAmaru'},
#              'Monta': {'BuenaVista'},
#              'MorroArica': {'Naranjos'},
#              'Naranjos': {'Billinhurst',
#                           'Cipreses',
#                           'Jacarandas',
#                           'ManuelPrado'},
#              'Narcisos': {'Amapolas', ' Hayllapampa'},
#              'NicolasPierola': {'12Febrero',
#                                 '23Septiembre',
#                                 'ArguedaSantamirado',
#                                 'Aux.TupacAmaru',
#                                 'Ayacucho',
#                                 'Jr.7Febrero',
#                                 'ManuelOdria',
#                                 'MicaelaBastidas',
#                                 'Primeravera',
#                                 'Recuay',
#                                 'SimonBolivar',
#                                 'VargasMachuca'},
#              'NicolasaTorres': {'PasajeF1'},
#              'Nirge': {'Leona', 'Tacna'},
#              'Nisperos': {'Romeros'},
#              'NuevaEsperanza': {'OscarBenavides'},
#              'NuevaEstrella': {'LaLibertad'},
#              'OjseOlaya': {'VargasMachuca'},
#              'Olaya': {'Aniya'},
#              'Olivos': {'Alisos'},
#              'Ollantaytambo': {'Av.SeñordeCaudivilla',
#                                'C.Paucartambo',
#                                'TambodeMora'},
#              'Orquideas': {'TorresPacifico'},
#              'OscarBenavides': {'AntonioRaimondi',
#                                 'ArguedasMaltamirano',
#                                 'Aux.TupacAmaru',
#                                 'Benites',
#                                 'Bolognesi',
#                                 'CarlosMariategui',
#                                 'Cendal',
#                                 'ChimpuOcllo',
#                                 'JoseSantosChocano',
#                                 'JulioCesarTello',
#                                 'Jzela',
#                                 'Kioto',
#                                 'LaBola',
#                                 'LaCultura',
#                                 'LeninSolano',
#                                 'LuSoli',
#                                 'ManuelODria',
#                                 'ManuelPrado',
#                                 'Marte',
#                                 'Pachacamau',
#                                 'ParadoBellido',
#                                 'Razuri',
#                                 'SalazarBondi',
#                                 'SanMartin',
#                                 'SanchezCarrion',
#                                 'SimonBolivar',
#                                 'Tokio',
#                                 'TupacAmaru',
#                                 'Valdelomar',
#                                 'Yen'},
#              'Pacaes': {'Lucumas'},
#              'Pacayal': {'Aux.Uni',
#                          'Claveles',
#                          'FedericoVillarreal',
#                          'Manzanos',
#                          'Margaritas',
#                          'Naranjos',
#                          'Principal'},
#              'Pacifico': {'Av.U', 'C.1'},
#              'PaloRosa': {' Begonias', 'CamaraReal'},
#              'PaloSanto': {'Cedros'},
#              'Palomas': {'LaUnion'},
#              'ParadoBellido': {' AndresCaceres',
#                                ' Benavides',
#                                ' Bolognesi',
#                                ' Jzela',
#                                ' ManuelPrado',
#                                ' Marte',
#                                ' Pachacamau',
#                                ' SanMartin',
#                                ' SanchezCarrion',
#                                ' TupacAmaru',
#                                ' VizcardoGuzman'},
#              'ParadoBerrido': {'VargasMachuca'},
#              'Paraizo': {'Maruja'},
#              'Pardo': {'Barreda'},
#              'PardoYBarreda': {'MiguelGrau'},
#              'ParqueCarlosEspinoza': {'C.22'},
#              'ParquePacayal': {'VirgenDelCarmen'},
#              'ParqueZonal': {' ParqueAdventista',
#                              'Aux.TupacAmaru',
#                              'C.11',
#                              'C.14',
#                              'C.17',
#                              'C.25',
#                              'Eucaliptos',
#                              'JrPacifico',
#                              'LasGlicinas',
#                              'LosCedros',
#                              'LosCrisantemos',
#                              'LosNisperos',
#                              'LosSauces',
#                              'MancoCapac',
#                              'ManuelPrado',
#                              'MarianoCondorcanqui',
#                              'TrapicheChillon',
#                              'TupacAmaru',
#                              'Universitaria'},
#              'Peonias': {'Aux.Uni', 'Pacayal'},
#              'Pereda': {'Acoscamayta',
#                         'Av.MarianoCondorcanqui',
#                         'C.10',
#                         'C.FranciscaHerrera'},
#              'Petunias': {'Lirios'},
#              'Pinos': {'Amapolas'},
#              'Piura': {'Alamos', 'Aves'},
#              'Pje.2': {'1Mayo'},
#              'Pje.A': {'VenturaMonjaras'},
#              'Primulas': {'Calindulas', 'Zinnias'},
#              'Principal': {'ManuelPrado',
#                            'ParqueMicheleTrefogli',
#                            'ParquePalmerasChillon'},
#              'ProlMerinoReyna': {'JoseCarlosMariategui'},
#              'Puruchuco': {'Ca.HuacadelSol'},
#              'RamonCastilla': {'Ayacucho', 'EliasAguirre'},
#              'Ranna': {'Sanna'},
#              'Recuay': {'3Octubre'},
#              'RicardoPalma': {'Unanue'},
#              'RocaEterna': {'ChavinHuantar'},
#              'Rogers': {'Linyan', 'Sucursal'},
#              'Romeros': {'Sihuas'},
#              'Rosales': {'Calle4', 'ParquePlanicie'},
#              'Rosas': {'Achiras', 'TorresPacifico'},
#              'SalasPachacutec': {'C.Huchura',
#                                  'C.MiguelLanda',
#                                  'Humboldt',
#                                  'Pereda'},
#              'SanFrancisco': {'Av.JoseCarlosMariategui',
#                               'Av.SeñordeCaudivilla',
#                               'C.Collasuyo',
#                               'C.Moscu',
#                               'Ca.Londres',
#                               'Calle5',
#                               'SanJuanBautista',
#                               'Trulio',
#                               'Yuta'},
#              'SanIsidro': {'SanFrancisco', 'Eucaliptos', 'Cedros', 'Chontas'},
#              'SanJose': {'LosGeranios'},
#              'SanJuanBautista': {'Av.JoseCarlosMariategui', 'SanMartin'},
#              'SanJudas': {'SanJuanBautista'},
#              'SanMartin': {'LosCedros',
#                            'Pinos',
#                            'SanFrancisco',
#                            'SantaMarta',
#                            'TupacAmaru'},
#              'SanPedroClavers': {'C.Y'},
#              'SanchezCarrion': {'Benitez'},
#              'SanchezCerro': {'12Febrero',
#                               '23Septiembre',
#                               'AntonioRaimondi',
#                               'ArguedaSantamirano',
#                               'Aux.TupacAmaru',
#                               'Aux.Uni',
#                               'Ayacucho',
#                               'CarlosMareategui',
#                               'Chimpuocllo',
#                               'JoseSantosChocano',
#                               'JulioCesarTello',
#                               'LaBola',
#                               'LeninSalino',
#                               'LosTulipanes',
#                               'LuisEnriqueI',
#                               'Luzoli',
#                               'Mamaocllo',
#                               'ManuelOdria',
#                               'MicaelaBastidas',
#                               'Primavera',
#                               'SalazarBondi',
#                               'SanMartin',
#                               'SanPedroCarabayllo',
#                               'SimonBolivar',
#                               'TupacAmaru',
#                               'Universitaria',
#                               'VargasMachuca',
#                               'Yen'},
#              'Sanna': {'Colla'},
#              'SantaAna': {'Ciruelos',
#                           'Margaritas',
#                           'SanFrancisco',
#                           'SantaMarta'},
#              'SantaElena': {'SanMartin', 'SantaAna'},
#              'SantaMarta': {'VirgenDelCarmen'},
#              'SantaRosa': {'Skynner', 'Geranlos'},
#              'Santeola': {'Reiko'},
#              'SantoDomingo': {'AguasMarinas',
#                               'Antisuyo',
#                               'C11',
#                               'Calle4',
#                               'CaminoReal',
#                               'Cipreses',
#                               'Jazmines',
#                               'ManuelPrado',
#                               'Pacayal',
#                               'Primulas',
#                               'RocaEterna',
#                               'Skinner',
#                               'Vasquez'},
#              'Santos': {'Uriarte'},
#              'Scorza': {'JavierHeraud'},
#              'Silvertes': {nan},
#              'Skynner': {'Jazmines'},
#              'SolNaciente': {'LosFaiques'},
#              'Tacna': {'Tacna2', 'Ica', 'Calle11'},
#              'Tawan': {' ElisabethLoginote'},
#              'TeresaCalcuta': {'MarcoCapac'},
#              'Toronjas': {'Ciruelas'},
#              'TorresPacifico': {'Aux.Uni',
#                                 'Campanillas',
#                                 'Magnolias',
#                                 'SantoDomingo',
#                                 'Tulipanes'},
#              'TrapicheChillon': {'Av.U',
#                                  'C.11',
#                                  'C.16',
#                                  'C.16 y Trapiche',
#                                  'C.18',
#                                  'C.22',
#                                  'C.4',
#                                  'C.5',
#                                  'C.9',
#                                  'C.R',
#                                  'C.S',
#                                  'C.U',
#                                  'C.V',
#                                  'C.Y',
#                                  'IglesiaBentista',
#                                  'Jr.Pacifico',
#                                  'ParqueZonal',
#                                  'TeresaCalcuta'},
#              'Tulipanes': {'Aux.TupacAmaru', 'Calveles', 'Retamas'},
#              'Tupac': {'M.Prado'},
#              'TupacAmaru': {'AlfonsoUgarte',
#                             'Billinghurst',
#                             'CaminoReal',
#                             'DelCarmen',
#                             'JosePardo',
#                             'LosCrisantemos',
#                             'LosGeranios',
#                             'LosRosales',
#                             'ManuelPrado',
#                             'Miraflores',
#                             'ParqueZonal',
#                             'SanchezCerro'},
#              'Union': {'Ayacucho', 'Ancash', 'America'},
#              'Universitaria': {'3Octubre',
#                                'AugustoLeguia',
#                                'Av.U',
#                                'C.17',
#                                'C.7',
#                                'C.Floresta',
#                                'C.M',
#                                'C.O',
#                                'Ca.Pazos',
#                                'CaminoReal',
#                                'ChavinHuantar',
#                                'Guaralino',
#                                'Gustamante',
#                                'LasFlores',
#                                'ManuelPrado',
#                                'ParqueZonal',
#                                'SanchesCerro',
#                                'Skinner'},
#              'Vasquez': {'LosJardines'},
#              'VenturaMonjaras': {'MiguelAnco', 'EstebanBaca', 'MelchorArteaga'},
#              'VictorHumareda': {'RicardoPalma', 'JoseMariaArguedas'},
#              'VirgenDelCarmen': {'TupacAmaru'},
#              'Yactayo': {'Aux.Uni', 'LaFlor'},
#              'Zinnias': {' Billinghurst'}})

# %%
import pandas as pd
import numpy as np
import graphviz as gv

# %%
roads = pd.read_csv("LibroCallesTp.csv")
#print(type(roads))
#print(roads.info())
listacalle1, listacalle2 = roads['calle'],roads['interseccion']
listaintersecciones = list()
num_registros = len(listacalle1)
for i in range(num_registros):
    calle1 = str(listacalle1[i])
    calle2 = str(listacalle2[i])
    nombre = calle1+';'+calle2
    nombre_inverso = calle2+';'+calle1
    if nombre not in listaintersecciones and nombre_inverso not in listaintersecciones:
        listaintersecciones.append(nombre)
#print(len(listaintersecciones))
#print(listaintersecciones)

conexiones = list() # Lista de conexiones entre intersecciones a traves de calles (bordes o arista que seran parte del grafo)
num_intersecciones = len(listaintersecciones)
for i in range(num_intersecciones-1):
    for j in range(i+1,num_intersecciones):
        nombre_i1, nombre_i2 = listaintersecciones[i].split(';')
        nombre_j1, nombre_j2 = listaintersecciones[j].split(';')
        if nombre_i1 == nombre_j1 or nombre_i1 == nombre_j2:
            nombre_calle = nombre_i1
            distancia  = np.random.randint(100,500)
            congestion  = np.random.randint(0,100)
            conexiones.append([listaintersecciones[i],listaintersecciones[j],nombre_calle,distancia,congestion]) 
            #conexiones.append([listaintersecciones[i],listaintersecciones[j],distancia])
        elif nombre_i2 == nombre_j1 or nombre_i2 == nombre_j2:
            nombre_calle = nombre_i2
            distancia  = np.random.randint(100,500)
            congestion  = np.random.randint(0,100)
            conexiones.append([listaintersecciones[i],listaintersecciones[j],nombre_calle,distancia,congestion])
            #conexiones.append([listaintersecciones[i],listaintersecciones[j],distancia])


#G[i].append(j,w) -> Tiene que acdeptar nombre de nodos que sea string, por que por el momento todos aceptaban numercos
#MST(G)
conexiones = conexiones[:round(0.10*len(conexiones))]
conexiones = conexiones[:40]
#print(len(conexiones))
print(conexiones)
#G = Graph(conexiones)



g = gv.Graph('G', filename='process.gv', engine='sfdp')
for conexion in conexiones:
    #g.edge(conexion[0], conexion[1], label=conexion[2]) #Mostrar calles que conectan
    g.edge(conexion[0], conexion[1], label=str(conexion[3])) #Mostrar distancia entre intersecciones
    #g.edge(conexion[0], conexion[1], label=str(conexion[4])+'%')

g.view()
# Out:
# [['CamaraReal;C.A', 'PaloRosa;CamaraReal', 'CamaraReal', 471, 58], ['CamaraReal;C.A', 'C.D;C.A', 'C.A', 244, 46], ['CamaraReal;C.A', 'C.A;C.Collasuyo', 'C.A', 134, 65], ['CamaraReal;C.A', 'CamaraReal;Av.A', 'CamaraReal', 135, 4], ['C.B;PaloRosa', 'PaloRosa;CamaraReal', 'PaloRosa', 295, 86], ['C.B;PaloRosa', 'C.B;C.Collasuyo', 'C.B', 494, 60], ['C.B;PaloRosa', 'C.Collasuyo;PaloRosa', 'PaloRosa', 208, 67], ['C.B;PaloRosa', 'PaloRosa; Begonias', 'PaloRosa', 445, 82], ['C.B;PaloRosa', 'LosSauces;PaloRosa', 'PaloRosa', 282, 81], ['PaloRosa;CamaraReal', 'C.Collasuyo;PaloRosa', 'PaloRosa', 109, 8], ['PaloRosa;CamaraReal', 'CamaraReal;Av.A', 'CamaraReal', 128, 45], ['PaloRosa;CamaraReal', 'PaloRosa; Begonias', 'PaloRosa', 295, 54], ['PaloRosa;CamaraReal', 'LosSauces;PaloRosa', 'PaloRosa', 463, 1], ['C.D;C.A', 'C.A;C.Collasuyo', 'C.A', 172, 18], ['C.D;C.A', 'C.Collasuyo;C.D', 'C.D', 299, 14], ['C.B;C.Collasuyo', 'C.Collasuyo;PaloRosa', 'C.Collasuyo', 345, 34], ['C.B;C.Collasuyo', 'C.A;C.Collasuyo', 'C.Collasuyo', 131, 69], ['C.B;C.Collasuyo', 'C.Collasuyo;C.D', 'C.Collasuyo', 393, 64], ['C.B;C.Collasuyo', 'C.10;C.Collasuyo', 'C.Collasuyo', 316, 43], ['C.B;C.Collasuyo', 'C.Collasuyo;C.11', 'C.Collasuyo', 281, 48], ['C.B;C.Collasuyo', 'C.12;C.Collasuyo', 'C.Collasuyo', 423, 22], ['C.B;C.Collasuyo', 'C.Collasuyo;C.13', 'C.Collasuyo', 487, 34], ['C.B;C.Collasuyo', 'C.Collasuyo;C.8', 'C.Collasuyo', 305, 15], ['C.B;C.Collasuyo', 'C.9;C.Collasuyo', 'C.Collasuyo', 225, 60], ['C.B;C.Collasuyo', 'ManuelPrado;C.Collasuyo', 'C.Collasuyo', 438, 81], ['C.B;C.Collasuyo', 'Chinchaysuyo;C.Collasuyo', 'C.Collasuyo', 461, 30], ['C.B;C.Collasuyo', 'AntisuyoCalleC;C.Collasuyo', 'C.Collasuyo', 200, 75], ['C.B;C.Collasuyo', 'C.Collasuyo;Ca.HuacadelSol', 'C.Collasuyo', 210, 39], ['C.B;C.Collasuyo', 'C.Collasuyo;C.MachuPicchu', 'C.Collasuyo', 388, 36], ['C.B;C.Collasuyo', 'C.Collasuyo;Contisuyo', 'C.Collasuyo', 433, 68], ['C.B;C.Collasuyo', 'C.Collasuyo;C.Paucartambo', 'C.Collasuyo', 483, 94], ['C.B;C.Collasuyo', 'C.Collasuyo;Av.SeñordeCaudivilla', 'C.Collasuyo', 194, 89], ['C.B;C.Collasuyo', 'C.Collasuyo;Ca.Mercadona', 'C.Collasuyo', 393, 92], ['C.B;C.Collasuyo', 'C.Collasuyo;C.G', 'C.Collasuyo', 295, 7], ['C.B;C.Collasuyo', 'C.Collasuyo;C.F', 'C.Collasuyo', 182, 19], ['C.B;C.Collasuyo', 'C.Collasuyo;Av.JoseCarlosMariategui', 'C.Collasuyo', 108, 30], ['C.B;C.Collasuyo', 'C.Collasuyo;Av.MerinoReynaOeste', 'C.Collasuyo', 452, 52], ['C.B;C.Collasuyo', 'SanFrancisco;C.Collasuyo', 'C.Collasuyo', 437, 1], ['C.Collasuyo;PaloRosa', 'C.A;C.Collasuyo', 'C.Collasuyo', 444, 62], ['C.Collasuyo;PaloRosa', 'C.Collasuyo;C.D', 'C.Collasuyo', 161, 8]]
# 'process.gv.pdf'

# %% [markdown]
# ###Probar clase con pesos (algoritmos de rutas)

# %%
from queue import PriorityQueue

class Graph:
    def __init__(self, num_of_vertices):
        self.v = num_of_vertices
        self.edges = [[-1 for i in range(num_of_vertices)] for j in range(num_of_vertices)]
        self.visited = []

    def add_edge(self, u, v, weight):
        self.edges[u][v] = weight
        self.edges[v][u] = weight

    def dijkstra(self, start_vertex):
        D = {v:float('inf') for v in range(self.v)}
        D[start_vertex] = 0

        pq = PriorityQueue()
        pq.put((0, start_vertex))

        while not pq.empty():
            (dist, current_vertex) = pq.get()
            self.visited.append(current_vertex)

            for neighbor in range(self.v):
                if self.edges[current_vertex][neighbor] != -1:
                    distance = self.edges[current_vertex][neighbor]
                    if neighbor not in self.visited:
                        old_cost = D[neighbor]
                        new_cost = D[current_vertex] + distance
                        if new_cost < old_cost:
                            pq.put((new_cost, neighbor))
                            D[neighbor] = new_cost
        return D

# %%
from collections import defaultdict


# Clase que usa lista de adyacencia 

class Graph:

    def __init__(self, vertices):
        self.V = vertices  # No. of vertices
        self.V_org = vertices
        self.graph = defaultdict(list)  # diccionario para grafo


    def addEdge(self,u,v,w,):
        if w == 1:
            self.graph[u].append(v)
        else:
            self.graph[u].append(self.V)
            self.graph[self.V].append(v)
            self.V = self.V + 1

    def printPath(self, parent, j):
        Path_len = 1
        if parent[j] == -1 and j < self.V_org:  # Base Case : If j is source
            print (j, ' ')
            return 0  # when parent[-1] then path length = 0
        l = self.printPath(parent, parent[j])
        Path_len = l + Path_len

        # imprime nodo si es menor que len del nodo original
        if j < self.V_org:
            print (j, ' ')

        return Path_len

    def findShortestPath(self, src, dest):

        # Mark all the vertices as not visited
        # Initialize parent[] and visited[]

        visited = [False] * self.V
        parent = [-1] * self.V

        # Cola de prioridad para BFS
        queue = []
        # Nodo de origen en cola y visitado
        queue.append(src)
        visited[src] = True

        while queue:
            s = queue.pop(0)
            if s == dest:
                return self.printPath(parent, s)
            # Get all adjacent vertices of the dequeued vertex s
            # If a adjacent has not been visited, then mark it
            # visited and enqueue it
            for i in self.graph[s]:
                if visited[i] == False:
                    queue.append(i)
                    visited[i] = True
                    parent[i] = s

# %%
roads = pd.read_csv("LibroCallesTp.csv")
#print(type(roads))
#print(roads.info())
listacalle1, listacalle2 = roads['calle'],roads['interseccion']
listaintersecciones = list()
num_registros = len(listacalle1)
for i in range(num_registros):
    calle1 = str(listacalle1[i])
    calle2 = str(listacalle2[i])
    nombre = calle1+';'+calle2
    nombre_inverso = calle2+';'+calle1
    if nombre not in listaintersecciones and nombre_inverso not in listaintersecciones:
        listaintersecciones.append(nombre)
#print(len(listaintersecciones))
#print(listaintersecciones)

# Diccionario que traduce de string a int para nodos
dict_pos_inter = {}
dict_inter_pos = {}
for i in range(len(listaintersecciones)):
  listaintersecciones[i] = [listaintersecciones[i], i] # Esto para facilitar el registro de conexiones
  dict_pos_inter[i] = listaintersecciones[i][0] # Esto para traducir luego de hacer el resultado del algoritmo
  dict_inter_pos[listaintersecciones[i][0]] = i  # Esto para traducir luego de hacer el resultado del algoritmo

conexiones = list() # Lista de conexiones entre intersecciones a traves de calles (bordes o arista que seran parte del grafo)
num_intersecciones = len(listaintersecciones)
for i in range(num_intersecciones-1):
    for j in range(i+1,num_intersecciones):
        nombre_i1, nombre_i2 = listaintersecciones[i][0].split(';')
        nombre_j1, nombre_j2 = listaintersecciones[j][0].split(';')
        if nombre_i1 == nombre_j1 or nombre_i1 == nombre_j2:
            nombre_calle = nombre_i1
            distancia  = np.random.randint(100,500)
            congestion  = np.random.randint(0,100)
            conexiones.append([listaintersecciones[i][1],listaintersecciones[j][1],distancia]) 
        elif nombre_i2 == nombre_j1 or nombre_i2 == nombre_j2:
            nombre_calle = nombre_i2
            distancia  = np.random.randint(100,500)
            congestion  = np.random.randint(0,100)
            conexiones.append([listaintersecciones[i][1],listaintersecciones[j][1],distancia])

conexiones = conexiones[:round(0.10*len(conexiones))]
conexiones = conexiones[:40]

g = Graph(num_intersecciones)
for conexion in conexiones:
  g.addEdge(conexion[0],conexion[1],conexion[2])
  g.addEdge(conexion[1],conexion[0],conexion[2])
  #print(conexion[0],conexion[1],conexion[2])

src_name = "C.Collasuyo;PaloRosa"
dest_name = "PaloRosa;CamaraReal"

src = dict_inter_pos[src_name]
dest = dict_inter_pos[dest_name]

print ("El camino mas corto entre ",src_name+" y "+dest_name+" es: ")
l = g.findShortestPath(src, dest)
if l == None:
  print("Estan desconectados")
# Out:
# El camino mas corto entre  C.Collasuyo;PaloRosa y PaloRosa;CamaraReal es:
# 5
# 2
