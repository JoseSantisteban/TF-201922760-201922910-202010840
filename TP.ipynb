# %%
import csv
import graphviz as gv

# %%
Calles1=[]
with open("LibroCallesTp.csv") as archivo:
  reader=csv.reader(archivo)
  for row in reader:
    Calles1.append(row)

# %%
Calles1
# Out:
# [['ï»¿calle', 'interseccion'],
#  ['CamaraReal', 'C.A'],
#  ['C.B', 'PaloRosa'],
#  ['PaloRosa', 'CamaraReal'],
#  ['C.D', 'C.A'],
#  ['C.B', 'C.Collasuyo'],
#  ['C.Collasuyo', 'PaloRosa'],
#  ['C.A', 'C.Collasuyo'],
#  ['C.Collasuyo', 'C.D'],
#  ['CamaraReal', 'Av.A'],
#  ['Huayallapampa', 'Cipreses'],
#  ['Tupac', 'M.Prado'],
#  ['M.Prado', 'SantoDomingo'],
#  ['SantoDomingo', 'CaminoReal'],
#  ['TrapicheChillon', 'ParqueZonal'],
#  ['ParqueZonal', 'MancoCapac'],
#  ['ParqueZonal', 'JrPacifico'],
#  ['Pacifico', 'C.1'],
#  ['Pacifico', 'Av.U'],
#  ['TrapicheChillon', 'Av.U'],
#  ['C.18', ' Av.U'],
#  ['CaminoReal', 'C.18'],
#  ['C.18', 'C.11'],
#  ['C.11', 'TrapicheChillon'],
#  ['CaminoReal', 'Malecon'],
#  ['Malecon', 'Jr.Sanjose'],
#  ['C.11', 'Malecon'],
#  ['Jr.SanJose', 'C.11'],
#  ['Collasuyo', 'Dalias'],
#  ['Dalias', 'SantoDomingo'],
#  ['Claudivilla', 'Dalias'],
#  ['LosAngeles', 'SantoDomingo'],
#  ['Cipreses', 'Amapolas'],
#  ['Naranjos', 'Cipreses'],
#  ['Naranjos', 'ManuelPrado'],
#  ['Custamante', 'SantaRosa'],
#  ['Universitaria', 'Gustamante'],
#  ['Bustamante', 'SanMartin'],
#  ['Bustamante', 'Nardos'],
#  ['Bustamante', 'Naranjos'],
#  ['Naranjos', 'Billinhurst'],
#  ['Jacintos', 'Naranjos'],
#  ['Acacias', 'Naranjos'],
#  ['Acacias', 'SantaRosa'],
#  ['Jacintos', 'SantaRosa'],
#  ['Biiinghurst', 'SantaRosa'],
#  ['Hayllapampa', 'ManuelPrado'],
#  ['Narcisos', ' Hayllapampa'],
#  ['Narcisos', 'Amapolas'],
#  ['Pinos', 'Amapolas'],
#  ['Amapolas', 'ManuelPrado'],
#  ['Amapolas', 'Cipreses'],
#  ['FlorCerezo', 'Hayllapampa'],
#  ['FlorLoto-Hayllapampa'],
#  ['Amapolas', 'Primulas'],
#  ['Zinnias', ' Billinghurst'],
#  ['Calendulas', 'Billinghurst'],
#  ['Billinghurst', 'SantoDomingo'],
#  ['Amapolas', 'Billinghurst'],
#  ['Amapolas', 'Archiras'],
#  ['Achiras', 'Naranjos'],
#  ['Achiras', 'SantoDomingo'],
#  ['Petunias', 'Lirios'],
#  ['Lirios', 'TorresPacifico'],
#  ['Amapolas', 'Petunias'],
#  ['Amapolas', 'TorresPacifico'],
#  ['TorresPacifico', 'SantoDomingo'],
#  ['Arandanos', 'Lirios'],
#  ['Arandanos', 'Naranjos'],
#  ['Lirios', 'Manzanos'],
#  ['SantoDomingo', 'Pacayal'],
#  ['Pacayal', 'Manzanos'],
#  ['Pacayal', 'Claveles'],
#  ['Claveles', 'Higos'],
#  ['Higos', 'Manzanos'],
#  ['Higos', 'Rosas'],
#  ['Rosas', 'TorresPacifico'],
#  ['Naranjos', 'Jacarandas'],
#  ['Ciruelas', 'TorresPacifico'],
#  ['Jacarandas', 'Ciruelas'],
#  ['TorresPacifico', 'Magnolias'],
#  ['Manzanos', 'Ciruelas'],
#  ['Higos', 'Ciruelas'],
#  ['Ciruelas', 'Claveles'],
#  ['Claveles', 'Magnolias'],
#  ['Claveles', 'Lucumas'],
#  ['Lucumas', 'Peonias'],
#  ['Peonias', 'Pacayal'],
#  ['Magnolias', 'Pacayal'],
#  ['Pacayal', 'FedericoVillarreal'],
#  ['Pacayal', 'Aux.Uni'],
#  ['Pacayal', 'Principal'],
#  ['Pacayal', 'Naranjos'],
#  ['Claveles', 'SantaRosa'],
#  ['Peonias', 'Aux.Uni'],
#  ['TorresPacifico', 'Aux.Uni'],
#  ['Billinghurst', 'Aux.Uni'],
#  ['Pacayal', 'Margaritas'],
#  ['Margaritas', 'AgustinGamarra'],
#  ['Aux.Uni', 'AgustinGamarra'],
#  ['AgustinGamarra', 'Carnelias'],
#  ['TorresPacifico', 'Tulipanes'],
#  ['Aun.Uni', 'Geranios'],
#  ['Geranios', 'Tulipanes'],
#  ['TorresPacifico', 'Campanillas'],
#  ['Campanillas', 'Retamas'],
#  ['Orquideas', 'TorresPacifico'],
#  ['Tulipanes', 'Retamas'],
#  ['Tulipanes', 'Calveles'],
#  ['Calveles', 'DienteLeon'],
#  ['LosAngeles', 'Principal'],
#  ['SantoDomingo', 'Cipreses'],
#  ['Collasuyo', 'LosAngeles'],
#  ['FlorLoto', 'Amapolas'],
#  ['SantoDomingo', 'Primulas'],
#  ['SantoDomingo', 'Primulas'],
#  ['Primulas', 'Zinnias'],
#  ['Primulas', 'Calindulas'],
#  ['Principal', 'ManuelPrado'],
#  ['Billinghurst', 'Lucumas'],
#  ['SantoDomingo', 'Pacayal'],
#  ['Billinghurst', 'Rosas'],
#  ['Rosales', 'Calle4'],
#  ['Rosales', 'ParquePlanicie'],
#  ['Aux.Uni', 'Luzmila'],
#  ['Luzmila', 'Gorriones'],
#  ['Gorriones', 'Pacayal'],
#  ['Margaritas', 'Luzmilla'],
#  ['Gorriones', 'Colibries'],
#  ['Colibries', 'Luzmilla'],
#  ['Luzmilla', 'Gorriones'],
#  ['Gorriones', 'SantaMarta'],
#  ['SantaAna', 'SantaMarta'],
#  ['Gorriones', 'VirgerDelCarmen'],
#  ['SantaElena', 'SantaAna'],
#  ['SantaAna', 'Margaritas'],
#  ['SantaAna', 'SanFrancisco'],
#  ['FedericoVillareal', 'Chayan'],
#  ['Aux.Uni', 'VirgenDelCarmen'],
#  ['VirgenDelCarmen', 'TupacAmaru'],
#  ['SantaMarta', 'VirgenDelCarmen'],
#  ['SantaElena', 'SanMartin'],
#  ['SanMartin', 'SantaMarta'],
#  ['Margaritas', 'SanMartin'],
#  ['Margaritas', 'VirgenDelCarmen'],
#  ['SanMartin', 'SanFrancisco'],
#  ['Ciruelos', 'SanMartin'],
#  ['SantaAna', 'Ciruelos'],
#  ['Ciruelos', 'SanIsidro'],
#  ['SanIsidro', 'SanFrancisco'],
#  ['Universitaria', 'Ca.Pazos'],
#  ['FedericoVillareal', 'Ca.Pazos'],
#  ['C.3', 'C.2'],
#  ['C.3', 'Aux.Uni'],
#  ['C.2', 'Aux.Uni'],
#  ['C.2', 'ParquePacayal'],
#  ['ParquePacayal', 'VirgenDelCarmen'],
#  ['SanIsidro', 'Eucaliptos'],
#  ['SanIsidro', 'Chontas'],
#  ['SanIsidro', 'Cedros'],
#  ['Chontas', 'SanMartin'],
#  ['Eucaliptos', 'SanMartin'],
#  ['SanMartin', 'LosCedros'],
#  ['SanMartin', 'Pinos'],
#  ['SanMartin', 'TupacAmaru'],
#  ['Principal', 'ParquePalmerasChillon'],
#  ['Principal', 'ParqueMicheleTrefogli'],
#  ['Cedros', 'Robles'],
#  ['Cedros', 'TupacAmaru'],
#  ['Manzanos', 'SantaRosa'],
#  ['Higos', 'Aux.Uni'],
#  ['Higos', 'SantaRosa'],
#  ['Higos', 'Magnolias'],
#  ['Jacarandas', 'Magnolias'],
#  ['Jacarandas', 'Lucumas'],
#  ['Rosas', 'Achiras'],
#  ['Achiras', 'Lucumas'],
#  ['Billinghurst', 'Tulipanes'],
#  ['Billinghurst', 'Orquideas'],
#  ['Billinghurst', '12Febrero'],
#  ['Ca.Pazos', 'ParqueFlorida'],
#  ['Av.A', 'LasFrambuesas'],
#  ['LasFrambuesas', 'LasManzanas'],
#  ['Manzanas', 'Lucumas'],
#  ['Frambuesas', 'Toronjas'],
#  ['Frambuesas', 'Duraznos'],
#  ['Toronjas', 'Ciruelas'],
#  ['Duraznos', 'Ciruelas'],
#  ['Ciruelas', 'Manzanas'],
#  ['Frambuesas', 'Pacaes'],
#  ['Pacaes', 'Lucumas'],
#  ['Lucumas', 'Fresas'],
#  ['Lucumas', 'Av.A'],
#  ['Fresas', 'Lucumas'],
#  ['Fresas', 'C.13'],
#  ['C.13', 'Avenue3'],
#  ['C.13', 'AymiTupac'],
#  ['AymiTupac', 'C.5'],
#  ['C.13', 'C.8'],
#  ['C.5', 'AymiTupac'],
#  ['AymiTupac', 'C.4'],
#  ['C.4', 'C.5'],
#  ['AymiTupac', 'C.9'],
#  ['C.4', 'Ca.3'],
#  ['C.4', 'C.9'],
#  ['C.9', 'Ca.3'],
#  ['C.9', 'C.12'],
#  ['C.12', 'C.7'],
#  ['C.9', 'C.8'],
#  ['C.9', 'C.7'],
#  ['C.9', 'AymiTupac'],
#  ['AymiTupac', 'C.10'],
#  ['AymiTupac', 'C.12'],
#  ['C.7', 'C.13'],
#  ['C.12', 'C.5'],
#  ['C.13', 'C.5'],
#  ['C.10', 'C.4'],
#  ['C.10', 'C.2'],
#  ['C.10', 'C.Collasuyo'],
#  ['C.Collasuyo', 'C.11'],
#  ['C.12', 'C.Collasuyo'],
#  ['C.Collasuyo', 'C.13'],
#  ['Ca.3', 'C.13'],
#  ['Ca.3', 'C.12'],
#  ['C.13', 'LosGallinazos'],
#  ['C.13', 'C.11'],
#  ['Gallinazos', 'C.11'],
#  ['C.11', 'C.Collasuyo'],
#  ['C.Collasuyo', 'C.8'],
#  ['C.2', 'Caudivilla'],
#  ['C.9', 'C.2'],
#  ['C.9', 'C.Collasuyo'],
#  ['C.9', 'Gallinazos'],
#  ['Gallinazos', 'C.5'],
#  ['C.5', 'C.9'],
#  ['C.5', 'C.10'],
#  ['C.9', 'C.7'],
#  ['C.9', 'C.Collasuyo'],
#  ['C.7', 'Ca.3'],
#  ['C.8', 'Ca.3'],
#  ['C.8', 'Caudivilla'],
#  ['CaminoReal', ' Universitaria'],
#  ['CaminoReal', 'ParqueZonal'],
#  ['Av.MarianoCondorcanqui', 'Av.U'],
#  ['TrapicheChillon', 'Jr.Pacifico'],
#  ['C.18', 'ManuelPrado'],
#  ['SantoDomingo', 'Antisuyo'],
#  ['Antisuyo', 'Contisuyo'],
#  ['Contisuyo', 'Collasuyo'],
#  ['LosSauces', 'Ca.2'],
#  ['LosSauces', 'LosGeranios'],
#  ['LosLaureles', 'VargasMachuca'],
#  ['JoseBalta', 'AugustoLeguia'],
#  ['23Septiembre', '12febrero'],
#  ['AugustoLeguia', '23Septiembre'],
#  ['LosAlgarrobos', 'C.O'],
#  ['C.V', 'C.O'],
#  ['MarianoCondorcanqui', 'Algarrobos'],
#  ['LosNogales', 'Bonsai'],
#  ['Aux.Uni', ' Universitaria'],
#  ['Cipreses', 'Lirios'],
#  ['Olivos', 'Alisos'],
#  ['Ficus', 'Alisos'],
#  ['PaloRosa', ' Begonias'],
#  ['PaloSanto', 'Cedros'],
#  ['SolNaciente', 'LosFaiques'],
#  ['LosFaiques', 'LosAlisis'],
#  ['MicaelaBastidas', 'LosAlamos'],
#  ['LosAlamos', 'LaRivera'],
#  ['LasCerezas', ' Los Alamos'],
#  ['LaRivera', 'LasGuanabanas'],
#  ['LosFaiques', 'LosTulipanes'],
#  ['LaRivera', 'Angamos'],
#  ['LasCerezas', 'Guanabanas'],
#  ['LosMangos', 'LosTulipanes'],
#  ['ElDorado', 'LasLlantanas'],
#  ['LasLlantanas', '31Mayo'],
#  ['LasCerezas', 'LosTulipanes'],
#  ['LasGerberas', '31Mayo'],
#  ['LosCrocus', 'ManuelScorza'],
#  ['ManuelScorza', 'LosAndes'],
#  ['LosAndes', 'Miraflores'],
#  ['Miraflores', '31Mayo'],
#  ['OscarBenavides', 'Razuri'],
#  ['LosCrocus', 'MicaelaBastidas'],
#  ['MicaelaBastidas', 'ManuesScorza'],
#  ['LosClaveles', 'LasGerberas'],
#  ['ParadoBerrido', 'VargasMachuca'],
#  ['LosPortales', 'RamonCastilla'],
#  ['RamonCastilla', 'Ayacucho'],
#  ['Ayacucho', 'MiguelGrau'],
#  ['EnriquePalacios', 'JoseOlaya'],
#  ['DiegoFerre', 'LosJuniperos'],
#  ['ParadoBellido', ' AndresCaceres'],
#  ['Recuay', '3Octubre'],
#  ['LaQuina', '3Octubre'],
#  ['NicolasPierola', 'Recuay'],
#  ['LosTulipanes', 'ElDorado'],
#  ['ManuelScorza', 'LosClaveles'],
#  ['LosJardines', 'LosPortales'],
#  ['RamonCastilla', 'EliasAguirre'],
#  ['LasGardenias', 'LosJardines'],
#  ['LosPortales', 'Ayacucho'],
#  ['PardoYBarreda', 'MiguelGrau'],
#  ['JoseOlaya', 'DiegoFerre'],
#  ['LosJuniperos', 'Angamos'],
#  ['DiegoFerre', 'Juniperos'],
#  ['OjseOlaya', 'VargasMachuca'],
#  ['AndresCaceres', 'Recuay'],
#  ['Angamos', 'LaQuina'],
#  ['LasTunas', '3Octubre'],
#  ['30Marzo', 'LasTunas'],
#  ['LasTunas', 'LasPalmas'],
#  ['EnriquePalacios', 'LosJuniperos'],
#  ['4Agosto', 'Nisperos'],
#  ['Nisperos', 'Romeros'],
#  ['Romeros', 'Sihuas'],
#  ['Carhuaz', 'Angamos'],
#  ['Ancash', 'LosRobles'],
#  ['LasHortencias', 'SolVilla'],
#  ['LaLibertad', 'Tulipanes'],
#  ['LaLibertad', 'Angamos'],
#  ['C.Q', ' C.21'],
#  ['C.21', 'C.24'],
#  ['C.24', 'C.Q'],
#  ['C.25', 'C.21'],
#  ['LosRobles', 'Tulipanes'],
#  ['NuevaEstrella', 'LaLibertad'],
#  ['C.Ayacucho', 'Ancash'],
#  ['Ancash', ' LaLibertad'],
#  ['Universitaria', 'C.M'],
#  ['C.25', 'C.20'],
#  ['C.Q', 'C.24'],
#  ['C.21', 'Universitaria'],
#  ['C.Q', 'Universitaria'],
#  ['Universitaria', 'C.17'],
#  ['Av.U', 'C.17'],
#  ['C.N', 'Av.U'],
#  ['C.14', 'C.N'],
#  ['C.N', 'C.LL'],
#  ['C.Q', 'C.N'],
#  ['C.Q', 'C.R'],
#  ['C.11', 'C.S'],
#  ['C.12', 'C.9'],
#  ['Universitaria', 'C.Floresta'],
#  ['C.Floresta', 'C.V'],
#  ['C.V', 'Av.U'],
#  ['Av.U', 'C.W'],
#  ['C.W', 'C.13'],
#  ['TrapicheChillon', 'C.16'],
#  ['C.Floresta', 'C.Y'],
#  ['C.Floresta', 'C.13'],
#  ['C.Y', 'C.9'],
#  ['CaminoReal', 'C.9'],
#  ['C.9', 'C.Y'],
#  ['C.Q', 'Claudivilla'],
#  ['Ca.3', 'Claudivilla'],
#  ['C.9', 'C.5'],
#  ['MancoCapac', 'TeresaCalcuta'],
#  ['SanPedroClavers', 'C.Y'],
#  ['Claudivilla', 'MancoCapac'],
#  ['TeresaCalcuta', 'MarcoCapac'],
#  ['SanPedroClavers', 'C.Y'],
#  ['C.Y', 'Parque15'],
#  ['C.Y', 'C.22'],
#  ['IglesiaAdventista', 'C.22'],
#  ['Av.U', 'IglesiaAdventista'],
#  ['Av.U', 'Jr.Pacifico'],
#  ['Jr.Pacifico', 'IglesiaAdventista'],
#  ['Calle1', 'Calle2'],
#  ['ParqueCarlosEspinoza', 'C.22'],
#  ['C.22', 'Calle3'],
#  ['C.18', 'C.22'],
#  ['Jr.Pacifico', 'C.18'],
#  ['Bytetect', ' ParqueCarabayllo'],
#  ['SantoDomingo', 'Calle4'],
#  ['C.11', 'Calle4'],
#  ['SantoDomingo', 'C11'],
#  ['C.18', 'Parque'],
#  ['Alinut', 'C.18'],
#  ['Achallau', 'LaFlor'],
#  ['LaFlor', 'Marcona'],
#  ['Yactayo', 'LaFlor'],
#  ['3Octubre', 'SantaRosa'],
#  ['Skynner', 'Jazmines'],
#  ['SantoDomingo', 'Jazmines'],
#  ['SantaRosa', 'Skynner'],
#  ['Yactayo', 'Aux.Uni'],
#  ['Jazmines', 'CaminoReal'],
#  ['ChavinHuantar', 'Hayllapampa'],
#  ['Carolina', 'LosJardines'],
#  ['RocaEterna', 'ChavinHuantar'],
#  ['Carolina', 'SantaRosa'],
#  ['Huaralino', 'ChavinHuantar'],
#  ['Casuarinas', 'AguasMarinas'],
#  ['Casuarinas', 'Skynner'],
#  ['Calle6', 'Huambos'],
#  ['Huaralino', 'Huambos'],
#  ['Calle6', 'LasFlores'],
#  ['Calle7', 'AguasMarinas'],
#  ['Vasquez', 'LosJardines'],
#  ['LasFlores', 'Calle7'],
#  ['ChavinHuantar', 'Huaralino'],
#  ['Calle7', 'Calle11'],
#  ['Calle7', 'Calle8'],
#  ['Calle8', 'Calle9'],
#  ['Calle8', 'Calle10'],
#  ['Calle10', 'Calle111'],
#  ['ManuelPrado', 'JosePardo'],
#  ['MicaelaBastidas', 'Tacna'],
#  ['Tacna', 'Calle11'],
#  ['Ica', '1Mayo'],
#  ['Florales', 'Ancash'],
#  ['Alegre', 'Ancash'],
#  ['Ayacucho', 'Union'],
#  ['America', 'Florales'],
#  ['Pje.2', '1Mayo'],
#  ['LaCapilla', 'Carmen'],
#  ['Aux.TupacAmaru', ' Carmen'],
#  ['9Octubre', 'America'],
#  ['SantaRosa', 'Geranlos'],
#  ['Geranlos', 'Tacna'],
#  ['Nirge', 'Tacna'],
#  ['Nirge', 'Leona'],
#  ['MicaelaBastidas', 'Tacna'],
#  ['Union', 'America'],
#  ['Union', 'Ayacucho'],
#  ['Union', 'Ancash'],
#  ['Milei', 'MicaelaBastidas'],
#  ['Michela', 'Milei'],
#  ['NuevaEsperanza', 'OscarBenavides'],
#  ['SanchezCarrion', 'Benitez'],
#  ['Jaricza', 'Santos'],
#  ['Jaricza', 'Uriarte'],
#  ['Centar', 'Santos'],
#  ['Benitez', 'SanchezCarrion'],
#  ['Michela', 'SanGabriel'],
#  ['Mendiola', 'Benitez'],
#  ['Santos', 'Uriarte'],
#  ['Olaya', 'Aniya'],
#  ['Frecker', 'Santos'],
#  ['Rogers', 'Sucursal'],
#  ['Rogers', 'Linyan'],
#  ['Tawan', ' ElisabethLoginote'],
#  ['ElisabethLoginote', 'Sucursal'],
#  ['L', 'N'],
#  ['L', 'J'],
#  ['C', 'J'],
#  ['Amapolas', 'Central'],
#  ['Central', 'Sauces'],
#  ['MorroArica', 'Naranjos'],
#  ['LosOlivos', 'Sauces'],
#  ['Galaspagos', 'Aves'],
#  ['Piura', 'Aves'],
#  ['Alarcon', '2Diciembre'],
#  ['Piura', 'Alamos'],
#  ['Chiclayo', 'Alhelles'],
#  ['Chiclayo', 'Piura'],
#  ['Tulipanes', 'Aux.TupacAmaru'],
#  ['Miraflores', 'Cantuta'],
#  ['Amancaes', 'AlfonsoUgarte'],
#  ['LosJazmines', 'LosCactus'],
#  ['Jr.Trebol', 'Cantuta'],
#  ['Jr.Trebol', 'Orquideas'],
#  ['Jr.Trebol', 'Cactus'],
#  ['3Diciembre', 'GarcilazoVega'],
#  ['Angeles', 'GarcilazoVega'],
#  ['3Diciembre', 'Angeles'],
#  ['LosRosales', 'LaUnion'],
#  ['Palomas', 'LaUnion'],
#  ['Cienpies', 'Santeola'],
#  ['Santeola', 'Reiko'],
#  ['Azucena', 'Reiko'],
#  ['Jazmines', 'Liurnia'],
#  ['Lucaria', 'Auxiliar'],
#  ['Cienpies', 'Liturgia'],
#  ['Lucario', 'Liturgia'],
#  ['SanJose', 'LosGeranios'],
#  ['ElDomo', 'LosLaureles'],
#  ['LosClaveles', 'LosLaureles'],
#  ['Jr7Febrero', 'SanMartin'],
#  ['Arguedas', 'Altamirano'],
#  ['LosGeranios', 'Lirios'],
#  ['Lirios', 'Sanna'],
#  ['Sanna', 'Colla'],
#  ['Ranna', 'Sanna'],
#  ['Colla', 'ManuelOdria'],
#  ['ManuelPardo', 'MiguelGrau'],
#  ['Cruz', 'Monique'],
#  ['CarlosMariategui', 'Cruz'],
#  ['Pardo', 'Barreda'],
#  ['3Octubre', 'Olivos'],
#  ['JoseBalta', 'NicolasPierola'],
#  ['AugistoLeguia', 'FloresNorte'],
#  ['Maruja', 'Loiza'],
#  ['Paraizo', 'Maruja'],
#  ['Maruja', 'Geminis'],
#  ['Monta', 'BuenaVista'],
#  ['LeninSolano', 'AndresCaceres'],
#  ['BuenaVista', 'SanchezCerro'],
#  ['CaminoReal', 'SolVilla'],
#  ['CaminoReal', 'Rivera'],
#  ['CaminoReal', 'LosPortales'],
#  ['CaminoReal', 'LosRomeros'],
#  ['CaminoReal', 'Eucaliptos'],
#  ['CaminoReal', 'C.Y'],
#  ['CaminoReal', 'Aux.Uni'],
#  ['CaminoReal', 'JazminesYCaminoReal'],
#  ['CaminoReal', 'SantoDomingo'],
#  ['CaminoReal', 'C.Q'],
#  ['CaminoReal', 'C.18'],
#  ['CaminoReal', 'MicaelaBastidas'],
#  ['CaminoReal', 'TupacAmaru'],
#  ['CaminoReal', 'LosSauces'],
#  ['AugustoLeguia', 'ManuelOdria'],
#  ['AugustoLeguia', 'Aux.TupacAmaru'],
#  ['AugustoLeguia', 'SimonBoliva'],
#  ['AugustoLeguia', 'ArguedaSantamirano'],
#  ['AugustoLeguia', 'CarlosMariategui'],
#  ['AugustoLeguia', 'LeninSolano'],
#  ['AugustoLeguia', 'AndresCaceres'],
#  ['AugustoLeguia', 'VargasMachuca'],
#  ['AugustoLeguia', 'Ayacucho'],
#  ['AugustoLeguia', 'MicaelaBastidas'],
#  ['AugustoLeguia', '23Septiembre'],
#  ['AugustoLeguia', 'Primavera'],
#  ['AugustoLeguia', '12Febrero'],
#  ['AugustoLeguia', 'LasGuanabanas'],
#  ['AugustoLeguia', 'LosTulipanes'],
#  ['AugustoLeguia', 'Aux.Universitaria'],
#  ['Universitaria', 'ManuelPrado'],
#  ['Universitaria', 'Skinner'],
#  ['Universitaria', 'C.7'],
#  ['Universitaria', 'LasFlores'],
#  ['Universitaria', '3Octubre'],
#  ['Universitaria', 'Guaralino'],
#  ['Universitaria', 'ChavinHuantar'],
#  ['Universitaria', 'CaminoReal'],
#  ['Universitaria', 'Av.U'],
#  ['Universitaria', 'ParqueZonal'],
#  ['Universitaria', 'C.O'],
#  ['Universitaria', 'SanchesCerro'],
#  ['Universitaria', 'AugustoLeguia'],
#  ['Aux.Uni', 'SanchesCerro'],
#  ['Aux.Uni', 'AugustoLeguia'],
#  ['Aux.Uni', 'LasTunas'],
#  ['Aux.Uni', '3Octubre'],
#  ['Aux.Uni', 'Recuay'],
#  ['Aux.Uni', 'Ayacucho'],
#  ['Aux.Uni', 'LosRobles'],
#  ['Aux.Uni', 'LasOrtencias'],
#  ['Aux.Uni', 'CaminoReal'],
#  ['Aux.Uni', 'LosAlamos'],
#  ['Aux.Uni', 'Parquezonal'],
#  ['Aux.Uni', 'ChavinHuantar'],
#  ['Aux.Uni', 'Huaralino'],
#  ['Aux.Uni', 'JardinesI'],
#  ['Aux.Uni', 'C.7'],
#  ['Aux.Uni', 'Skinner'],
#  ['SantoDomingo', 'ManuelPrado'],
#  ['SantoDomingo', 'Skinner'],
#  ['SantoDomingo', 'AguasMarinas'],
#  ['SantoDomingo', 'Vasquez'],
#  ['SantoDomingo', 'RocaEterna'],
#  ['SantoDomingo', 'Jazmines'],
#  ['SantoDomingo', 'CaminoReal'],
#  ['TrapicheChillon', 'C.18'],
#  ['TrapicheChillon', 'C.11'],
#  ['TrapicheChillon', 'C.16 y Trapiche'],
#  ['TrapicheChillon', 'C.4'],
#  ['TrapicheChillon', 'C.Y'],
#  ['TrapicheChillon', 'C.V'],
#  ['TrapicheChillon', 'C.18'],
#  ['TrapicheChillon', 'C.22'],
#  ['TrapicheChillon', 'C.U'],
#  ['TrapicheChillon', 'C.9'],
#  ['TrapicheChillon', 'C.5'],
#  ['TrapicheChillon', 'C.S'],
#  ['TrapicheChillon', 'C.R'],
#  ['TrapicheChillon', 'IglesiaBentista'],
#  ['TrapicheChillon', 'TeresaCalcuta'],
#  ['TrapicheChillon', 'ParqueZonal'],
#  ['TupacAmaru', 'Billinghurst'],
#  ['TupacAmaru', 'ManuelPrado'],
#  ['TupacAmaru', 'SanchezCerro'],
#  ['TupacAmaru', 'LosRosales'],
#  ['TupacAmaru', 'AlfonsoUgarte'],
#  ['TupacAmaru', 'Miraflores'],
#  ['TupacAmaru', 'CaminoReal'],
#  ['TupacAmaru', 'LosCrisantemos'],
#  ['TupacAmaru', 'DelCarmen'],
#  ['TupacAmaru', 'LosGeranios'],
#  ['TupacAmaru', 'JosePardo'],
#  ['TupacAmaru', 'ParqueZonal'],
#  ['Aux.TupacAmaru', ' JosePardo'],
#  ['Aux.TupacAmaru', ' ParqueZonal'],
#  ['Aux.TupacAmaru', ' DelCarmen'],
#  ['Aux.TupacAmaru', 'PasajeGeranios'],
#  ['Aux.TupacAmaru', 'Central'],
#  ['Aux.TupacAmaru', 'LosCrisantemos'],
#  ['Aux.TupacAmaru', 'CaminoReal'],
#  ['Aux.TupacAmaru', 'ElDorado'],
#  ['Aux.TupacAmaru', 'Florales'],
#  ['Aux.TupacAmaru', 'Miraflores'],
#  ['Aux.TupacAmaru', 'Lazmines'],
#  ['Aux.TupacAmaru', 'AlfonsoUgarte'],
#  ['Aux.TupacAmaru', 'LosRosales'],
#  ['Aux.TupacAmaru', 'LosGeranios'],
#  ['Aux.TupacAmaru', 'LosLaureles'],
#  ['Aux.TupacAmaru', 'LosClaveles'],
#  ['Aux.TupacAmaru', 'MiguelGrau'],
#  ['Aux.TupacAmaru', 'PardoYBarreda'],
#  ['Aux.TupacAmaru', '3Octubre'],
#  ['Aux.TupacAmaru', 'JoseBalta'],
#  ['Aux.TupacAmaru', 'NicolasPierola'],
#  ['Aux.TupacAmaru', 'AugustoLeguia'],
#  ['Aux.TupacAmaru', 'AndresCaceres'],
#  ['Aux.TupacAmaru', 'RamonCastilla'],
#  ['Aux.TupacAmaru', 'SanchezCerro'],
#  ['Aux.TupacAmaru', 'ManuelPrado'],
#  ['Aux.TupacAmaru', 'BustamanteRivero'],
#  ['Aux.TupacAmaru', 'SamaneSocampo'],
#  ['Aux.TupacAmaru', 'OscarBenavides'],
#  ['OscarBenavides', 'SanchezCarrion'],
#  ['OscarBenavides', 'Benites'],
#  ['OscarBenavides', 'ParadoBellido'],
#  ['OscarBenavides', 'Marte'],
#  ['OscarBenavides', 'Bolognesi'],
#  ['OscarBenavides', 'SanMartin'],
#  ['OscarBenavides', 'Pachacamau'],
#  ['OscarBenavides', 'Razuri'],
#  ['OscarBenavides', 'ManuelPrado'],
#  ['OscarBenavides', 'Jzela'],
#  ['OscarBenavides', 'TupacAmaru'],
#  ['OscarBenavides', 'Kioto'],
#  ['OscarBenavides', 'Tokio'],
#  ['OscarBenavides', 'Cendal'],
#  ['OscarBenavides', 'Yen'],
#  ['OscarBenavides', 'LaBola'],
#  ['OscarBenavides', 'LuSoli'],
#  ['OscarBenavides', 'JulioCesarTello'],
#  ['OscarBenavides', 'SalazarBondi'],
#  ['OscarBenavides', 'Valdelomar'],
#  ['OscarBenavides', 'AntonioRaimondi'],
#  ['OscarBenavides', 'JoseSantosChocano'],
#  ['OscarBenavides', 'ChimpuOcllo'],
#  ['OscarBenavides', 'LaCultura'],
#  ['OscarBenavides', 'LeninSolano'],
#  ['OscarBenavides', 'CarlosMariategui'],
#  ['OscarBenavides', 'ArguedasMaltamirano'],
#  ['OscarBenavides', 'SimonBolivar'],
#  ['OscarBenavides', 'ManuelODria'],
#  ['OscarBenavides', 'Aux.TupacAmaru'],
#  ['ManuelPrado', ' SantoDomingo'],
#  ['ManuelPrado', 'Huayllapampa'],
#  ['ManuelPrado', ' LosNaranjos'],
#  ['ManuelPrado', 'SantaRosa'],
#  ['ManuelPrado', 'Aux.Uni'],
#  ['ManuelPrado', 'Universitaria'],
#  ['ManuelPrado', '12Febrero'],
#  ['ManuelPrado', 'Primeravera'],
#  ['ManuelPrado', '23Septiembre'],
#  ['ManuelPrado', 'MicaelaBastidas'],
#  ['ManuelPrado', 'Ayacucho'],
#  ['ManuelPrado', 'Aux.TupacAmaru'],
#  ['ManuelPrado', 'Jazminez'],
#  ['ManuelPrado', 'TupacAmaru'],
#  ['ManuelPrado', 'ManuelODria'],
#  ['ManuelPrado', 'SimonBolivar'],
#  ['ManuelPrado', 'MargaritaBelFast'],
#  ['ManuelPrado', 'ArguedazSantamirado'],
#  ['ManuelPrado', 'CarlosMareategui'],
#  ['ManuelPrado', 'LeninSolano'],
#  ['ManuelPrado', 'LaCultura'],
#  ['ManuelPrado', 'SanPedroCarabayllo'],
#  ['ManuelPrado', 'LuisEnriqueI'],
#  ['ManuelPrado', 'Chimpuocllo'],
#  ['ManuelPrado', 'AntonioRaimondi'],
#  ['ManuelPrado', 'SalazarBondi'],
#  ['ManuelPrado', 'JulioCesarTello'],
#  ['ManuelPrado', 'LuzOli'],
#  ['ManuelPrado', 'LaBola'],
#  ['ManuelPrado', 'Yen'],
#  ['ManuelPrado', 'Sendal'],
#  ['ManuelPrado', 'Tokio'],
#  ['ManuelPrado', 'Kioto'],
#  ['ManuelPrado', 'TupacAmaru'],
#  ['ManuelPrado', 'Jzela'],
#  ['ManuelPrado', 'ParadoBellido'],
#  ['ManuelPrado', 'OscarBenavides'],
#  ['ManuelPrado', 'MicaelaBastidas'],
#  ['ManuelPrado', 'FrancisVega'],
#  ['ManuelPrado', 'C.Collasuyo'],
#  ['ManuelPrado', 'Kioto'],
#  ['Benavides', 'SanchezCarrion'],
#  ['Benavides', 'Benites'],
#  ['Benavides', 'ParadoBellido'],
#  ['Benavides', 'Marte'],
#  ['Benavides', 'LaTierra'],
#  ['Benavides', 'SanMartin'],
#  ['Benavides', 'Pachacamau'],
#  ['Benavides', 'Rasauri'],
#  ['Benavides', 'ManuelPrado'],
#  ['Benavides', 'Jzela'],
#  ['Benavides', 'Kioto'],
#  ['Benavides', 'CoronelSandoval'],
#  ['Benavides', 'Tokio'],
#  ['Silvertes'],
#  ['Benavides', 'Zendal'],
#  ['Benavides', 'Yen'],
#  ['Benavides', 'LaBola'],
#  ['Benavides', 'Luzoli'],
#  ['Benavides', 'JulioCesarTello'],
#  ['Benavides', 'SalazarBondi'],
#  ['Benavides', 'Baldelomar'],
#  ['Benavides', 'AntonioRaimondi'],
#  ['Benavides', 'JoseSantosChocano'],
#  ['Benavides', 'Chimpuocllo'],
#  ['Benavides', 'LaCultura'],
#  ['Benavides', 'LeninSolano'],
#  ['Benavides', 'CarlosMareategui'],
#  ['Benavides', 'ArguedazSantamirado'],
#  ['Benavides', 'MargaritaVelfas'],
#  ['Benavides', 'ManuelOdria'],
#  ['Benavides', 'Aux.TupacAmaru'],
#  ['LosGeranios', ' Caudivilla'],
#  ['LosGeranios', 'MicaelaBastidas'],
#  ['LosGeranios', 'VargasMachuca'],
#  ['LosGeranios', 'LosSauces'],
#  ['LosGeranios', 'Aux.TupacAmaru'],
#  ['LosGeranios', 'Orquideas'],
#  ['LosGeranios', 'LosLaureles'],
#  ['LosGeranios', 'SimonBolivar'],
#  ['LosGeranios', 'Tulipanes'],
#  ['LosGeranios', 'Angeles'],
#  ['LosGeranios', 'SanJose'],
#  ['LosGeranios', 'Colla'],
#  ['LosGeranios', 'Lirios'],
#  ['JosePardo', 'Tacna'],
#  ['Tacna', 'Ica'],
#  ['Tacna', 'Tacna2'],
#  ['Ica', 'Ica2'],
#  ['MicaelaBastidas', 'Anylla'],
#  ['MicaelaBastidas', 'Frecker'],
#  ['MicaelaBastidas', '1Mayo'],
#  ['MicaelaBastidas', 'ElisabethLoginote'],
#  ['MicaelaBastidas', 'SanGabriel'],
#  ['MicaelaBastidas', 'Michela'],
#  ['MicaelaBastidas', 'DelCarmen'],
#  ['MicaelaBastidas', 'Paloma'],
#  ['MicaelaBastidas', 'Collasuyo'],
#  ['MicaelaBastidas', 'C.7'],
#  ['MicaelaBastidas', 'SantaRosa'],
#  ['MicaelaBastidas', 'Palmera'],
#  ['MicaelaBastidas', 'Leona'],
#  ['MicaelaBastidas', 'Geranlos'],
#  ['MicaelaBastidas', 'Geranlos2'],
#  ['MicaelaBastidas', 'LosClaveles'],
#  ['MicaelaBastidas', '3Octubre'],
#  ['MicaelaBastidas', 'ManuelPrado'],
#  ['MicaelaBastidas', 'RamonCastilla'],
#  ['MicaelaBastidas', 'SanchezCerro'],
#  ['MicaelaBastidas', 'AndresCaceres'],
#  ['MicaelaBastidas', 'AugustoLeguia'],
#  ['MicaelaBastidas', 'NicolasPierola'],
#  ['MicaelaBastidas', 'JoseBalta'],
#  ['MicaelaBastidas', 'PardoBarreda'],
#  ['MicaelaBastidas', '3Octubre'],
#  ['MicaelaBastidas', 'MiguelGrau'],
#  ['MicaelaBastidas', 'EnriquePalacios'],
#  ['MicaelaBastidas', 'EliasAguirre'],
#  ['MicaelaBastidas', 'LosLaureles'],
#  ['MicaelaBastidas', 'DiegoFerre'],
#  ['MicaelaBastidas', 'JoseOlaya'],
#  ['MicaelaBastidas', '31Mayo'],
#  ['MicaelaBastidas', 'AvenidaAngamos'],
#  ['MicaelaBastidas', 'ManuelEscorza'],
#  ['MicaelaBastidas', 'LosCrocus'],
#  ['MicaelaBastidas', 'LasLantanas'],
#  ['MicaelaBastidas', 'LosTulipanes'],
#  ['MicaelaBastidas', 'CaminoReal'],
#  ['MicaelaBastidas', 'SolNaciente'],
#  ['MicaelaBastidas', 'LosAlamos'],
#  ['MicaelaBastidas', 'LosRosales'],
#  ['MicaelaBastidas', 'LasPalmeras'],
#  ['MicaelaBastidas', 'LosPinos'],
#  ['MicaelaBastidas', '1Mayo'],
#  ['MicaelaBastidas', 'Milei'],
#  ['MicaelaBastidas', 'SanGabriel'],
#  ['MicaelaBastidas', 'Palmeras'],
#  ['MicaelaBastidas', 'SantaRosa'],
#  ['MicaelaBastidas', 'DelCarmen'],
#  ['ParqueZonal', 'ManuelPrado'],
#  ['ParqueZonal', 'LosSauces'],
#  ['ParqueZonal', 'Aux.TupacAmaru'],
#  ['ParqueZonal', 'TupacAmaru'],
#  ['ParqueZonal', 'LosCedros'],
#  ['ParqueZonal', 'LosCrisantemos'],
#  ['ParqueZonal', 'LasGlicinas'],
#  ['ParqueZonal', 'LosNisperos'],
#  ['ParqueZonal', 'Eucaliptos'],
#  ['ParqueZonal', 'Universitaria'],
#  ['ParqueZonal', 'C.25'],
#  ['ParqueZonal', 'MarianoCondorcanqui'],
#  ['ParqueZonal', 'C.17'],
#  ['ParqueZonal', 'C.14'],
#  ['ParqueZonal', 'C.11'],
#  ['ParqueZonal', 'TrapicheChillon'],
#  ['ParqueZonal', ' ParqueAdventista'],
#  ['ParqueZonal', 'MancoCapac'],
#  ['ParqueZonal', 'JrPacifico'],
#  ['Av.U', 'Jr.Pacifico'],
#  ['Av.U', 'C.18'],
#  ['Av.U', 'C.22'],
#  ['Av.U', 'TrapicheChillon'],
#  ['Av.U', 'Calle.W'],
#  ['Av.U', 'MarianoCondorcanqui'],
#  ['Av.U', 'C.9'],
#  ['Av.U', 'C.21'],
#  ['Av.U', 'CalleFlorestala'],
#  ['Av.U', 'Av.U2'],
#  ['Av.U', 'Floresta'],
#  ['Av.U', 'C.23'],
#  ['Av.U', 'C.25'],
#  ['Av.U', 'C.Q'],
#  ['Av.U', 'Universitaria'],
#  ['Av.U', 'Parque15'],
#  ['Av.U', 'C.Y'],
#  ['Miraflores', '2Diciembre'],
#  ['Miraflores', '3Diciembre'],
#  ['Miraflores', 'Cartura'],
#  ['Miraflores', 'Jr.Trebol'],
#  ['Miraflores', 'Avancaes'],
#  ['Miraflores', 'Tulipanes'],
#  ['Miraflores', 'Alamos'],
#  ['Miraflores', 'Alcones'],
#  ['Miraflores', 'Orquideas'],
#  ['Miraflores', 'Aux.TupacAmaru'],
#  ['Miraflores', 'TupacAmaru'],
#  ['Miraflores', 'LosSauces'],
#  ['Miraflores', 'Claudivilla'],
#  ['Miraflores', 'ManuelScorza'],
#  ['LosAndes', 'LosSauces'],
#  ['LosAndes', 'Claudivilla'],
#  ['LosAndes', 'Angamos'],
#  ['LosAndes', 'ManuelScorza'],
#  ['Angamos', 'LosSauces'],
#  ['Angamos', 'Claudivilla'],
#  ['Angamos', 'LosAndes'],
#  ['Angamos', 'ManuelScorza'],
#  ['Angamos', 'MicaelaBastidas'],
#  ['Angamos', '31Mayo'],
#  ['Angamos', 'LosJuniperos'],
#  ['Angamos', 'ParadoBellido'],
#  ['Angamos', 'DiegoFerre'],
#  ['Angamos', 'LosLaureles'],
#  ['Angamos', 'EliasAguirre'],
#  ['Angamos', 'EnriquePalacios'],
#  ['Angamos', 'PardoBarreda'],
#  ['Angamos', 'MiguelGrau'],
#  ['Angamos', 'LaRivera'],
#  ['Angamos', 'Recuay'],
#  ['Angamos', '3Octubre'],
#  ['Angamos', 'LasTunas'],
#  ['Angamos', 'LasPalmas'],
#  ['Angamos', 'LaQuina'],
#  ['Angamos', 'LosCerezos'],
#  ['12Febrero', 'ManuelPrado'],
#  ['12Febrero', '30Marzo'],
#  ['12Febrero', '4Agosto'],
#  ['12Febrero', 'AugustoLeguia'],
#  ['12Febrero', 'NicolasPierola'],
#  ['NicolasPierola', 'Primeravera'],
#  ['NicolasPierola', '23Septiembre'],
#  ['NicolasPierola', '12Febrero'],
#  ['NicolasPierola', 'MicaelaBastidas'],
#  ['NicolasPierola', 'Ayacucho'],
#  ['NicolasPierola', 'VargasMachuca'],
#  ['NicolasPierola', 'Aux.TupacAmaru'],
#  ['NicolasPierola', 'ManuelOdria'],
#  ['NicolasPierola', 'ArguedaSantamirado'],
#  ['NicolasPierola', 'SimonBolivar'],
#  ['NicolasPierola', 'Jr.7Febrero'],
#  ['JoseBalta', 'SanJose'],
#  ['JoseBalta', 'Olivos'],
#  ['JoseBalta', 'Jr.7Febrero'],
#  ['JoseBalta', 'CarlosMareategui'],
#  ['JoseBalta', 'ArguedaSantamirano'],
#  ['JoseBalta', 'SimonBolivar'],
#  ['JoseBalta', 'ManuelOdria'],
#  ['JoseBalta', 'Aux.TupacAmaru'],
#  ['JoseBalta', 'VargasMachuca'],
#  ['JoseBalta', 'Ayacucho'],
#  ['MicaelaBastidas'],
#  ['23Septiembre', '4Agosto'],
#  ['23Septiembre', 'SanchezCerro'],
#  ['23Septiembre', 'ManuelPrado'],
#  ['23Septiembre', 'AugustoLeguia'],
#  ['23Septiembre', 'NicolasPierola'],
#  ['23Septiembre', '3Octubre'],
#  ['23Septiembre', 'PardoBarreda'],
#  ['23Septiembre', 'SanchezCerro'],
#  ['SanchezCerro', 'Aux.Uni'],
#  ['SanchezCerro', 'Universitaria'],
#  ['SanchezCerro', 'LosTulipanes'],
#  ['SanchezCerro', '12Febrero'],
#  ['SanchezCerro', 'Primavera'],
#  ['SanchezCerro', '23Septiembre'],
#  ['SanchezCerro', 'MicaelaBastidas'],
#  ['SanchezCerro', 'Ayacucho'],
#  ['SanchezCerro', 'VargasMachuca'],
#  ['SanchezCerro', 'Aux.TupacAmaru'],
#  ['SanchezCerro', 'TupacAmaru'],
#  ['SanchezCerro', 'ManuelOdria'],
#  ['SanchezCerro', 'SimonBolivar'],
#  ['SanchezCerro', 'ArguedaSantamirano'],
#  ['SanchezCerro', 'CarlosMareategui'],
#  ['SanchezCerro', 'LeninSalino'],
#  ['SanchezCerro', 'SanPedroCarabayllo'],
#  ['SanchezCerro', 'LuisEnriqueI'],
#  ['SanchezCerro', 'Chimpuocllo'],
#  ['SanchezCerro', 'SanMartin'],
#  ['SanchezCerro', 'Mamaocllo'],
#  ['SanchezCerro', 'JoseSantosChocano'],
#  ['SanchezCerro', 'AntonioRaimondi'],
#  ['SanchezCerro', 'SalazarBondi'],
#  ['SanchezCerro', 'JulioCesarTello'],
#  ['SanchezCerro', 'Luzoli'],
#  ['SanchezCerro', 'LaBola'],
#  ['SanchezCerro', 'Yen'],
#  ['Collasuyo', 'Luzoli'],
#  ['Collasuyo', 'Yen'],
#  ['Collasuyo', 'Zendal'],
#  ['Collasuyo', 'Silvertes'],
#  ['Collasuyo', 'Tokio'],
#  ['Collasuyo', 'CoronelManuelSandoval'],
#  ['Collasuyo', 'Kioto'],
#  ['Collasuyo', 'ManuelPrado'],
#  ['Collasuyo', 'ParadoBellido'],
#  ['ParadoBellido', ' TupacAmaru'],
#  ['ParadoBellido', ' Jzela'],
#  ['ParadoBellido', ' ManuelPrado'],
#  ['ParadoBellido', ' Pachacamau'],
#  ['ParadoBellido', ' SanMartin'],
#  ['ParadoBellido', ' Bolognesi'],
#  ['ParadoBellido', ' Marte'],
#  ['ParadoBellido', ' Benavides'],
#  ['ParadoBellido', ' SanchezCarrion'],
#  ['JoseRivaguero'],
#  ['ParadoBellido', ' VizcardoGuzman'],
#  ['Eucaliptos', 'ParqueZonal'],
#  ['Eucaliptos', 'ElBosque'],
#  ['Eucaliptos', 'LosLirios'],
#  ['Eucaliptos', 'LosCipreses'],
#  ['Eucaliptos', 'LosPinos'],
#  ['Eucaliptos', 'Bonsai'],
#  ['Eucaliptos', 'LasPalmeras'],
#  ['Eucaliptos', 'LosRosales'],
#  ['Eucaliptos', 'LosAlamos'],
#  ['Eucaliptos', 'CaminoReal'],
#  ['MarianoCondorcanqui', 'ParqueZonal'],
#  ['MarianoCondorcanqui', 'C.M'],
#  ['MarianoCondorcanqui', 'C.N'],
#  ['MarianoCondorcanqui', 'C.O'],
#  ['MarianoCondorcanqui', 'C.R'],
#  ['MarianoCondorcanqui', 'C.21'],
#  ['MarianoCondorcanqui', 'C.Q'],
#  ['MarianoCondorcanqui', 'S'],
#  ['MarianoCondorcanqui', 'C23'],
#  ['MarianoCondorcanqui', 'SanPedroClaves'],
#  ['MarianoCondorcanqui', 'Av.U'],
#  ['LosCipreses', 'Eucaliptos'],
#  ['LosCipreses', 'Nisperos'],
#  ['LosCipreses', 'LosNogales'],
#  ['LosCipreses', 'LosCrisantemos'],
#  ['LosOlivos', 'LosCedros'],
#  ['LosOlivos', 'LosCrisantemos'],
#  ['LosOlivos', 'LosFicus'],
#  ['LosOlivos', 'LosAlisos'],
#  ['LosOlivos', 'LasGlicinas'],
#  ['LosOlivos', 'LosNogales'],
#  ['LosOlivos', 'Valegre'],
#  ['LosOlivos', '1Mayo'],
#  ['LosOlivos', 'Central'],
#  ['LosOlivos', 'Galapagos'],
#  ['LosSauces', 'ParqueZonal'],
#  ['LosSauces', 'Collasuyo'],
#  ['LosSauces', 'LosAlgarrobos'],
#  ['LosSauces', 'Cuadra2'],
#  ['LosSauces', 'Contisuyo'],
#  ['LosSauces', 'Antisuyo'],
#  ['LosSauces', 'PaloRosa'],
#  ['LosSauces', 'PaloSanto'],
#  ['LosSauces', 'LosCedros'],
#  ['LosSauces', 'LosCrisantemos'],
#  ['LosSauces', 'LosFicus'],
#  ['LosSauces', 'SolNaciente'],
#  ['LosSauces', 'CaminoReal'],
#  ['LosSauces', 'LosTulipanes'],
#  ['LosSauces', 'ElDorado'],
#  ...]

# %%
def DibujarGrafo(Grafo, Dirige=False, Camino=[]):
  Grafico = gv.Digraph("felicidad") if Dirige else gv.Graph("alegria")
  n = len(Grafo)
  added = set()
  for Columna, Fila in enumerate(Camino):
    if Fila != -1:
      Grafico.edge(str(Fila), str(Columna), dir="forward", penwidth="2", color="orange")
      added.add(f"{Fila},{Columna}")
      added.add(f"{Columna},{Fila}")
  for Fila in range(n):
    for Columna in Grafo[Fila]:
      if not Dirige and not f"{Fila},{Columna}" in added:  
        added.add(f"{Fila},{Columna}")
        added.add(f"{Columna},{Fila}")
        Grafico.edge(str(Fila), str(Columna))
      elif Dirige:
        Grafico.edge(str(Fila), str(Columna))
  return Grafico

DibujarGrafo(Calles1)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Users\JOSE MAURICIO\AppData\Local\Programs\Python\Python39\lib\site-packages\graphviz\backend\execute.py:79, in run_check(cmd, input_lines, encoding, quiet, **kwargs)
#      78         kwargs['stdout'] = kwargs['stderr'] = subprocess.PIPE
# ---> 79     proc = _run_input_lines(cmd, input_lines, kwargs=kwargs)
#      80 else:
#
# File c:\Users\JOSE MAURICIO\AppData\Local\Programs\Python\Python39\lib\site-packages\graphviz\backend\execute.py:99, in _run_input_lines(cmd, input_lines, kwargs)
#      98 def _run_input_lines(cmd, input_lines, *, kwargs):
# ---> 99     popen = subprocess.Popen(cmd, stdin=subprocess.PIPE, **kwargs)
#     101     stdin_write = popen.stdin.write
#
# File c:\Users\JOSE MAURICIO\AppData\Local\Programs\Python\Python39\lib\subprocess.py:951, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask)
#     948             self.stderr = io.TextIOWrapper(self.stderr,
#     949                     encoding=encoding, errors=errors)
# --> 951     self._execute_child(args, executable, preexec_fn, close_fds,
#     952                         pass_fds, cwd, env,
#     953                         startupinfo, creationflags, shell,
#     954                         p2cread, p2cwrite,
#     955                         c2pread, c2pwrite,
#     956                         errread, errwrite,
#     957                         restore_signals,
#     958                         gid, gids, uid, umask,
#     959                         start_new_session)
#     960 except:
#     961     # Cleanup if the child failed starting.
#
# File c:\Users\JOSE MAURICIO\AppData\Local\Programs\Python\Python39\lib\subprocess.py:1420, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_gid, unused_gids, unused_uid, unused_umask, unused_start_new_session)
#    1419 try:
# -> 1420     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1421                              # no special security
#    1422                              None, None,
#    1423                              int(not close_fds),
#    1424                              creationflags,
#    1425                              env,
#    1426                              cwd,
#    1427                              startupinfo)
#    1428 finally:
#    1429     # Child is launched. Close the parent's copy of those pipe
#    1430     # handles that only the child should have open.  You need
#    (...)
#    1433     # pipe will not close when the child process exits and the
#    1434     # ReadFile will hang.
#
# FileNotFoundError: [WinError 2] El sistema no puede encontrar el archivo especificado
#
# The above exception was the direct cause of the following exception:
#
# ExecutableNotFound                        Traceback (most recent call last)
# File c:\Users\JOSE MAURICIO\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\formatters.py:973, in MimeBundleFormatter.__call__(self, obj, include, exclude)
#     970     method = get_real_method(obj, self.print_method)
#     972     if method is not None:
# --> 973         return method(include=include, exclude=exclude)
#     974     return None
#     975 else:
#
# File c:\Users\JOSE MAURICIO\AppData\Local\Programs\Python\Python39\lib\site-packages\graphviz\jupyter_integration.py:98, in JupyterIntegration._repr_mimebundle_(self, include, exclude, **_)
#      96 include = set(include) if include is not None else {self._jupyter_mimetype}
#      97 include -= set(exclude or [])
# ---> 98 return {mimetype: getattr(self, method_name)()
#      99         for mimetype, method_name in MIME_TYPES.items()
#     100         if mimetype in include}
#
# File c:\Users\JOSE MAURICIO\AppData\Local\Programs\Python\Python39\lib\site-packages\graphviz\jupyter_integration.py:98, in <dictcomp>(.0)
#      96 include = set(include) if include is not None else {self._jupyter_mimetype}
#      97 include -= set(exclude or [])
# ---> 98 return {mimetype: getattr(self, method_name)()
#      99         for mimetype, method_name in MIME_TYPES.items()
#     100         if mimetype in include}
#
# File c:\Users\JOSE MAURICIO\AppData\Local\Programs\Python\Python39\lib\site-packages\graphviz\jupyter_integration.py:112, in JupyterIntegration._repr_image_svg_xml(self)
#     110 def _repr_image_svg_xml(self) -> str:
#     111     """Return the rendered graph as SVG string."""
# --> 112     return self.pipe(format='svg', encoding=SVG_ENCODING)
#
# File c:\Users\JOSE MAURICIO\AppData\Local\Programs\Python\Python39\lib\site-packages\graphviz\piping.py:104, in Pipe.pipe(self, format, renderer, formatter, neato_no_op, quiet, engine, encoding)
#      55 def pipe(self,
#      56          format: typing.Optional[str] = None,
#      57          renderer: typing.Optional[str] = None,
#    (...)
#      61          engine: typing.Optional[str] = None,
#      62          encoding: typing.Optional[str] = None) -> typing.Union[bytes, str]:
#      63     """Return the source piped through the Graphviz layout command.
#      64
#      65     Args:
#    (...)
#     102         '<?xml version='
#     103     """
# --> 104     return self._pipe_legacy(format,
#     105                              renderer=renderer,
#     106                              formatter=formatter,
#     107                              neato_no_op=neato_no_op,
#     108                              quiet=quiet,
#     109                              engine=engine,
#     110                              encoding=encoding)
#
# File c:\Users\JOSE MAURICIO\AppData\Local\Programs\Python\Python39\lib\site-packages\graphviz\_tools.py:171, in deprecate_positional_args.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     162     wanted = ', '.join(f'{name}={value!r}'
#     163                        for name, value in deprecated.items())
#     164     warnings.warn(f'The signature of {func.__name__} will be reduced'
#     165                   f' to {supported_number} positional args'
#     166                   f' {list(supported)}: pass {wanted}'
#     167                   ' as keyword arg(s)',
#     168                   stacklevel=stacklevel,
#     169                   category=category)
# --> 171 return func(*args, **kwargs)
#
# File c:\Users\JOSE MAURICIO\AppData\Local\Programs\Python\Python39\lib\site-packages\graphviz\piping.py:121, in Pipe._pipe_legacy(self, format, renderer, formatter, neato_no_op, quiet, engine, encoding)
#     112 @_tools.deprecate_positional_args(supported_number=2)
#     113 def _pipe_legacy(self,
#     114                  format: typing.Optional[str] = None,
#    (...)
#     119                  engine: typing.Optional[str] = None,
#     120                  encoding: typing.Optional[str] = None) -> typing.Union[bytes, str]:
# --> 121     return self._pipe_future(format,
#     122                              renderer=renderer,
#     123                              formatter=formatter,
#     124                              neato_no_op=neato_no_op,
#     125                              quiet=quiet,
#     126                              engine=engine,
#     127                              encoding=encoding)
#
# File c:\Users\JOSE MAURICIO\AppData\Local\Programs\Python\Python39\lib\site-packages\graphviz\piping.py:149, in Pipe._pipe_future(self, format, renderer, formatter, neato_no_op, quiet, engine, encoding)
#     146 if encoding is not None:
#     147     if codecs.lookup(encoding) is codecs.lookup(self.encoding):
#     148         # common case: both stdin and stdout need the same encoding
# --> 149         return self._pipe_lines_string(*args, encoding=encoding, **kwargs)
#     150     try:
#     151         raw = self._pipe_lines(*args, input_encoding=self.encoding, **kwargs)
#
# File c:\Users\JOSE MAURICIO\AppData\Local\Programs\Python\Python39\lib\site-packages\graphviz\backend\piping.py:212, in pipe_lines_string(engine, format, input_lines, encoding, renderer, formatter, neato_no_op, quiet)
#     206 cmd = dot_command.command(engine, format,
#     207                           renderer=renderer,
#     208                           formatter=formatter,
#     209                           neato_no_op=neato_no_op)
#     210 kwargs = {'input_lines': input_lines, 'encoding': encoding}
# --> 212 proc = execute.run_check(cmd, capture_output=True, quiet=quiet, **kwargs)
#     213 return proc.stdout
#
# File c:\Users\JOSE MAURICIO\AppData\Local\Programs\Python\Python39\lib\site-packages\graphviz\backend\execute.py:84, in run_check(cmd, input_lines, encoding, quiet, **kwargs)
#      82 except OSError as e:
#      83     if e.errno == errno.ENOENT:
# ---> 84         raise ExecutableNotFound(cmd) from e
#      85     raise
#      87 if not quiet and proc.stderr:
#
# ExecutableNotFound: failed to execute WindowsPath('dot'), make sure the Graphviz executables are on your systems' PATH
